# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_hist_gradient_boosting  
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import median_absolute_error
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from matplotlib.patches import ConnectionPatch

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")
df_sub = pd.read_csv("sample_submission.csv")

df_train = df_train.drop(columns="ID")
df_test = df_test.drop(columns="ID")

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# from statsmodels.tools.tools import add_constant


# df_train_with_const = add_constant(df_train) 


# vif_data = pd.DataFrame()
# vif_data["feature"] = df_train_with_const.columns
# vif_data["VIF"] = [variance_inflation_factor(df_train_with_const.values, i) for i in range(df_train_with_const.shape[1])]

# print(vif_data)

# %%
# vif_data = vif_data[vif_data['feature'] != 'const']
# plt.figure(figsize=(10, 6))
# plt.barh(vif_data['feature'], vif_data['VIF'], color='skyblue')
# plt.xlabel('VIF')
# plt.ylabel('Feature')
# plt.title('Variance Inflation Factor (VIF)')
# plt.grid(axis='x')
# plt.show()

# %%
# numeric_columns = df_train.select_dtypes(include=['float64', 'int64'])

# def dist(train_dataset, columns_list, rows, cols):
#     fig, axs = plt.subplots(rows, cols, figsize=(40, 20))
#     axs = axs.flatten()
#     for i, col in enumerate(columns_list):
#         sns.kdeplot(train_dataset[col], ax=axs[i], fill=True, alpha=0.5, linewidth=0.5, color='#058279', label='Train')
#         axs[i].set_title(f'{col}, Train skewness: {train_dataset[col].skew():.2f}')
#         axs[i].legend()
#         axs[i].axis('off')
#         axs[i].set_xticks([])
#         axs[i].set_yticks([])
#         median_train = train_dataset[col].median()
#         axs[i].axvline(x=median_train, color='#4caba4', linestyle='--')
#         axs[i].legend(labels=['Train', 'Median'])
        
#     fig.suptitle('Distribution of Numeric Columns', fontsize=30)
#     plt.tight_layout()
#     sns.despine(left=True, bottom=True) 

# dist(train_dataset=df_train, columns_list=numeric_columns.columns, rows=4, cols=6)

# %%
X = df_train
y = df_train["y"]

# %%
from scipy.stats import entropy
from scipy.signal import welch,find_peaks


def count_peaks(row):
    peaks, _ = find_peaks(row)
    return len(peaks)

def spectral_entropy(row):
    _, psd = welch(row)
    return entropy(psd)

def cleaning(dataset):
    
    features = dataset.columns.tolist() 
    dataset['mean_features'] = 0.1 * dataset[features].mean(axis=1)
    dataset['std_features'] = dataset[features].std(axis=1)
    dataset['max_features'] = dataset[features].max(axis=1)
    dataset['min_features'] = dataset[features].min(axis=1)
    dataset['range_features'] = dataset['max_features'] - dataset['min_features']
    dataset['variance_features'] = dataset[features].var(axis=1)
    dataset['skewness_features'] = dataset[features].skew(axis=1)
    dataset['sum_features'] = dataset[features].sum(axis=1)

   
    mean_abs_dev = (dataset[features] - dataset[features].mean(axis=1).values.reshape(-1, 1)).abs().mean(axis=1)
    median_abs_dev = (dataset[features] - dataset[features].median(axis=1).values.reshape(-1, 1)).abs().mean(axis=1)
    range_abs_diff = (dataset[features] - dataset[features].median(axis=1).values.reshape(-1, 1)).abs().max(axis=1) - (dataset[features] - dataset[features].median(axis=1).values.reshape(-1, 1)).abs().min(axis=1)
    geometric_mean = np.exp(np.log(dataset[features].replace(0, 1)).mean(axis=1))
    harmonic_mean = len(features) / (1 / dataset[features].replace(0, 1)).sum(axis=1)
    coeff_variation = dataset['std_features'] / dataset['mean_features']

   
    quartiles = dataset[features].quantile([0.25, 0.5, 0.75], axis=1)
    dataset['first_quartile'] = quartiles.loc[0.25]
    dataset['second_quartile'] = quartiles.loc[0.5]
    dataset['third_quartile'] = quartiles.loc[0.75]

 
    kurtosis_features = dataset[features].kurtosis(axis=1)
    dataset['kurtosis_features'] = kurtosis_features

    dataset['mean_absolute_deviation'] = mean_abs_dev
    dataset['median_absolute_deviation'] = median_abs_dev
    dataset['range_abs_diff'] = range_abs_diff
    dataset['geometric_mean'] = geometric_mean
    dataset['harmonic_mean'] = harmonic_mean
    dataset['coeff_variation'] = coeff_variation
    
    # peak_features = dataset[features].apply(count_peaks, axis=1)
    # dataset['peak_frequency'] = peak_features
    
    # spectral_entropy_features = dataset[features].apply(spectral_entropy, axis=1)
    # dataset['spectral_entropy'] = spectral_entropy_features   


    # entropy_features = dataset[features].apply(entropy, axis=1)
    # dataset['entropy'] = entropy_features

    # dataset.drop(features, axis=1, inplace=True)

    return dataset

# %%
# df_train = cleaning(df_train)
# df_test = cleaning(df_test)

# %%
# X_train, X_valid = train_test_split(X, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_train_data = df_train
scaled_test_data = df_train

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold
from xgboost import XGBRegressor



xgb_params ={'n_estimators':600,
             'max_depth': 10,
           
             'learning_rate': 0.06,
             'random_state':42,
             }
             

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

xgb_predictions = np.zeros(len(scaled_train_data))
xgb_true_labels = np.zeros(len(scaled_train_data))
xgb_test_predictions = np.zeros(len(scaled_test_data))

for fold, (train_idx, val_idx) in enumerate(kf.split(scaled_train_data, y)):
    X_train, X_val = scaled_train_data.iloc[train_idx], scaled_train_data.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    xgb_model = XGBRegressor(**xgb_params)

    xgb_model.fit(X_train, y_train,
                  eval_set=[(X_train, y_train), (X_val, y_val)],
                  # early_stopping_rounds=10,
                  verbose=100)

    xgb_fold_preds = xgb_model.predict(X_val)
    xgb_fold_test_preds = xgb_model.predict(scaled_test_data)

    xgb_predictions[val_idx] = xgb_fold_preds
    xgb_true_labels[val_idx] = y_val
    xgb_test_predictions += xgb_fold_test_preds / n_splits  


overall_metric_xgb = r2_score(xgb_true_labels, xgb_predictions)
print("Overall R^2 (XGBRegressor):", overall_metric_xgb)
# Out:
# [0]	validation_0-rmse:2.53414	validation_1-rmse:2.51639
# [100]	validation_0-rmse:0.02938	validation_1-rmse:0.18155
# [200]	validation_0-rmse:0.01494	validation_1-rmse:0.18169
# [300]	validation_0-rmse:0.01121	validation_1-rmse:0.18178
# [400]	validation_0-rmse:0.00898	validation_1-rmse:0.18183
# [500]	validation_0-rmse:0.00750	validation_1-rmse:0.18186
# [599]	validation_0-rmse:0.00643	validation_1-rmse:0.18188
# [0]	validation_0-rmse:2.53699	validation_1-rmse:2.50379
# [100]	validation_0-rmse:0.02864	validation_1-rmse:0.18000
# [200]	validation_0-rmse:0.01487	validation_1-rmse:0.18153
# [300]	validation_0-rmse:0.01096	validation_1-rmse:0.18157
# [400]	validation_0-rmse:0.00890	validation_1-rmse:0.18162
# [500]	validation_0-rmse:0.00744	validation_1-rmse:0.18167
# [599]	validation_0-rmse:0.00631	validation_1-rmse:0.18165
# [0]	validation_0-rmse:2.51512	validation_1-rmse:2.59601
# [100]	validation_0-rmse:0.03047	validation_1-rmse:0.27705
# [200]	validation_0-rmse:0.01485	validation_1-rmse:0.25939
# [300]	validation_0-rmse:0.01094	validation_1-rmse:0.25902
# [400]	validation_0-rmse:0.00894	validation_1-rmse:0.25904
# [500]	validation_0-rmse:0.00760	validation_1-rmse:0.25905
# [599]	validation_0-rmse:0.00653	validation_1-rmse:0.25906
# [0]	validation_0-rmse:2.54321	validation_1-rmse:2.47797
# [100]	validation_0-rmse:0.02943	validation_1-rmse:0.66440
# [200]	validation_0-rmse:0.01476	validation_1-rmse:0.68039
# [300]	validation_0-rmse:0.01082	validation_1-rmse:0.68050
# [400]	validation_0-rmse:0.00877	validation_1-rmse:0.68058
# [500]	validation_0-rmse:0.00720	validation_1-rmse:0.68060
# [599]	validation_0-rmse:0.00628	validation_1-rmse:0.68060
# [0]	validation_0-rmse:2.52401	validation_1-rmse:2.56584
# [100]	validation_0-rmse:0.03328	validation_1-rmse:0.41858
# [200]	validation_0-rmse:0.01518	validation_1-rmse:0.38771
# [300]	validation_0-rmse:0.01178	validation_1-rmse:0.38709
# [400]	validation_0-rmse:0.00943	validation_1-rmse:0.38713
# [500]	validation_0-rmse:0.00778	validation_1-rmse:0.38715
# [599]	validation_0-rmse:0.00666	validation_1-rmse:0.38715
# Overall R^2 (XGBRegressor): 0.9793581773280821

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold


n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
catboost_params ={
             'random_state':42,
             'learning_rate': 0.011277016304363601, 
             'depth': 8, 
             'subsample': 0.8675506657380021, 
             'colsample_bylevel': 0.7183884158632279, 
             'min_data_in_leaf': 98
            }
catboost_predictions = np.zeros(len(scaled_train_data))
catboost_true_labels = np.zeros(len(scaled_train_data))
catboost_test_predictions = np.zeros(len(scaled_test_data))

for fold, (train_idx, val_idx) in enumerate(kf.split(scaled_train_data, y)):
    X_train, X_val = scaled_train_data.iloc[train_idx], scaled_train_data.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    catboost_model = CatBoostRegressor(**catboost_params)

    catboost_model.fit(X_train, y_train,
                       eval_set=(X_val, y_val),
                       early_stopping_rounds=10)

    catboost_fold_preds = catboost_model.predict(X_val)
    
    catboost_fold_test_preds = catboost_model.predict(scaled_test_data)

    catboost_predictions[val_idx] = catboost_fold_preds
    catboost_true_labels[val_idx] = y_val
    catboost_test_predictions += catboost_fold_test_preds / n_splits 

overall_metric_catboost = r2_score(catboost_true_labels, catboost_predictions)
print("Overall R^2 (CatBoostRegressor):", overall_metric_catboost)
# Out:
# 0:	learn: 2.6653163	test: 2.6474844	best: 2.6474844 (0)	total: 11.4ms	remaining: 11.4s
# 1:	learn: 2.6386888	test: 2.6199350	best: 2.6199350 (1)	total: 19.4ms	remaining: 9.68s
# 2:	learn: 2.6129517	test: 2.5934152	best: 2.5934152 (2)	total: 121ms	remaining: 40.1s
# 3:	learn: 2.5873331	test: 2.5670880	best: 2.5670880 (3)	total: 127ms	remaining: 31.7s
# 4:	learn: 2.5611286	test: 2.5401678	best: 2.5401678 (4)	total: 138ms	remaining: 27.4s
# 5:	learn: 2.5356264	test: 2.5139236	best: 2.5139236 (5)	total: 144ms	remaining: 23.9s
# 6:	learn: 2.5095454	test: 2.4871057	best: 2.4871057 (6)	total: 162ms	remaining: 23s
# 7:	learn: 2.4845189	test: 2.4613165	best: 2.4613165 (7)	total: 170ms	remaining: 21.1s
# 8:	learn: 2.4600344	test: 2.4361503	best: 2.4361503 (8)	total: 177ms	remaining: 19.5s
# 9:	learn: 2.4357245	test: 2.4111001	best: 2.4111001 (9)	total: 184ms	remaining: 18.2s
# 10:	learn: 2.4116267	test: 2.3861762	best: 2.3861762 (10)	total: 188ms	remaining: 16.9s
# 11:	learn: 2.3876801	test: 2.3612551	best: 2.3612551 (11)	total: 193ms	remaining: 15.9s
# 12:	learn: 2.3636064	test: 2.3364698	best: 2.3364698 (12)	total: 198ms	remaining: 15s
# 13:	learn: 2.3398867	test: 2.3120116	best: 2.3120116 (13)	total: 203ms	remaining: 14.3s
# 14:	learn: 2.3170155	test: 2.2883029	best: 2.2883029 (14)	total: 208ms	remaining: 13.6s
# 15:	learn: 2.2941304	test: 2.2648463	best: 2.2648463 (15)	total: 213ms	remaining: 13.1s
# 16:	learn: 2.2729251	test: 2.2427833	best: 2.2427833 (16)	total: 218ms	remaining: 12.6s
# 17:	learn: 2.2501151	test: 2.2190864	best: 2.2190864 (17)	total: 223ms	remaining: 12.2s
# 18:	learn: 2.2282016	test: 2.1962189	best: 2.1962189 (18)	total: 227ms	remaining: 11.7s
# 19:	learn: 2.2058280	test: 2.1729422	best: 2.1729422 (19)	total: 232ms	remaining: 11.4s
# 20:	learn: 2.1847537	test: 2.1514486	best: 2.1514486 (20)	total: 236ms	remaining: 11s
# 21:	learn: 2.1636343	test: 2.1295850	best: 2.1295850 (21)	total: 240ms	remaining: 10.7s
# 22:	learn: 2.1423890	test: 2.1078705	best: 2.1078705 (22)	total: 245ms	remaining: 10.4s
# 23:	learn: 2.1208457	test: 2.0858492	best: 2.0858492 (23)	total: 249ms	remaining: 10.1s
# 24:	learn: 2.0998383	test: 2.0640202	best: 2.0640202 (24)	total: 254ms	remaining: 9.89s
# 25:	learn: 2.0790382	test: 2.0429083	best: 2.0429083 (25)	total: 258ms	remaining: 9.68s
# 26:	learn: 2.0586927	test: 2.0218841	best: 2.0218841 (26)	total: 264ms	remaining: 9.51s
# 27:	learn: 2.0386692	test: 2.0012308	best: 2.0012308 (27)	total: 268ms	remaining: 9.31s
# 28:	learn: 2.0188984	test: 1.9806552	best: 1.9806552 (28)	total: 274ms	remaining: 9.16s
# 29:	learn: 1.9994676	test: 1.9604409	best: 1.9604409 (29)	total: 279ms	remaining: 9.02s
# 30:	learn: 1.9796570	test: 1.9398163	best: 1.9398163 (30)	total: 284ms	remaining: 8.87s
# 31:	learn: 1.9599209	test: 1.9191996	best: 1.9191996 (31)	total: 289ms	remaining: 8.73s
# 32:	learn: 1.9413705	test: 1.8998420	best: 1.8998420 (32)	total: 294ms	remaining: 8.62s
# 33:	learn: 1.9224470	test: 1.8801308	best: 1.8801308 (33)	total: 298ms	remaining: 8.46s
# 34:	learn: 1.9028624	test: 1.8601656	best: 1.8601656 (34)	total: 302ms	remaining: 8.32s
# 35:	learn: 1.8845657	test: 1.8410432	best: 1.8410432 (35)	total: 306ms	remaining: 8.18s
# 36:	learn: 1.8666034	test: 1.8222577	best: 1.8222577 (36)	total: 310ms	remaining: 8.06s
# 37:	learn: 1.8486792	test: 1.8033955	best: 1.8033955 (37)	total: 314ms	remaining: 7.94s
# 38:	learn: 1.8316089	test: 1.7854895	best: 1.7854895 (38)	total: 319ms	remaining: 7.85s
# 39:	learn: 1.8143403	test: 1.7679125	best: 1.7679125 (39)	total: 323ms	remaining: 7.75s
# 40:	learn: 1.7973449	test: 1.7505484	best: 1.7505484 (40)	total: 327ms	remaining: 7.65s
# 41:	learn: 1.7799474	test: 1.7325715	best: 1.7325715 (41)	total: 332ms	remaining: 7.57s
# 42:	learn: 1.7622704	test: 1.7144774	best: 1.7144774 (42)	total: 337ms	remaining: 7.49s
# 43:	learn: 1.7465140	test: 1.6978509	best: 1.6978509 (43)	total: 341ms	remaining: 7.41s
# 44:	learn: 1.7301634	test: 1.6807287	best: 1.6807287 (44)	total: 346ms	remaining: 7.34s
# 45:	learn: 1.7130979	test: 1.6632763	best: 1.6632763 (45)	total: 351ms	remaining: 7.28s
# 46:	learn: 1.6961686	test: 1.6458432	best: 1.6458432 (46)	total: 356ms	remaining: 7.22s
# 47:	learn: 1.6799460	test: 1.6291248	best: 1.6291248 (47)	total: 361ms	remaining: 7.16s
# 48:	learn: 1.6639442	test: 1.6122184	best: 1.6122184 (48)	total: 366ms	remaining: 7.11s
# 49:	learn: 1.6492103	test: 1.5969775	best: 1.5969775 (49)	total: 371ms	remaining: 7.04s
# 50:	learn: 1.6347831	test: 1.5817565	best: 1.5817565 (50)	total: 375ms	remaining: 6.97s
# 51:	learn: 1.6191041	test: 1.5658077	best: 1.5658077 (51)	total: 380ms	remaining: 6.92s
# 52:	learn: 1.6037823	test: 1.5498594	best: 1.5498594 (52)	total: 384ms	remaining: 6.86s
# 53:	learn: 1.5886783	test: 1.5344649	best: 1.5344649 (53)	total: 388ms	remaining: 6.8s
# 54:	learn: 1.5736148	test: 1.5186425	best: 1.5186425 (54)	total: 393ms	remaining: 6.76s
# 55:	learn: 1.5591589	test: 1.5035478	best: 1.5035478 (55)	total: 398ms	remaining: 6.72s
# 56:	learn: 1.5445228	test: 1.4881100	best: 1.4881100 (56)	total: 403ms	remaining: 6.66s
# 57:	learn: 1.5305435	test: 1.4737448	best: 1.4737448 (57)	total: 407ms	remaining: 6.61s
# 58:	learn: 1.5168642	test: 1.4598200	best: 1.4598200 (58)	total: 412ms	remaining: 6.57s
# 59:	learn: 1.5025285	test: 1.4452825	best: 1.4452825 (59)	total: 416ms	remaining: 6.52s
# 60:	learn: 1.4884720	test: 1.4305954	best: 1.4305954 (60)	total: 421ms	remaining: 6.47s
# 61:	learn: 1.4743803	test: 1.4161145	best: 1.4161145 (61)	total: 426ms	remaining: 6.45s
# 62:	learn: 1.4603200	test: 1.4016910	best: 1.4016910 (62)	total: 430ms	remaining: 6.4s
# 63:	learn: 1.4470079	test: 1.3875190	best: 1.3875190 (63)	total: 435ms	remaining: 6.36s
# 64:	learn: 1.4337597	test: 1.3735561	best: 1.3735561 (64)	total: 439ms	remaining: 6.31s
# 65:	learn: 1.4201977	test: 1.3597329	best: 1.3597329 (65)	total: 444ms	remaining: 6.28s
# 66:	learn: 1.4072044	test: 1.3464229	best: 1.3464229 (66)	total: 448ms	remaining: 6.24s
# 67:	learn: 1.3947261	test: 1.3336010	best: 1.3336010 (67)	total: 453ms	remaining: 6.21s
# 68:	learn: 1.3813445	test: 1.3196852	best: 1.3196852 (68)	total: 458ms	remaining: 6.18s
# 69:	learn: 1.3684070	test: 1.3063896	best: 1.3063896 (69)	total: 463ms	remaining: 6.15s
# 70:	learn: 1.3558699	test: 1.2935899	best: 1.2935899 (70)	total: 467ms	remaining: 6.11s
# 71:	learn: 1.3439468	test: 1.2808136	best: 1.2808136 (71)	total: 471ms	remaining: 6.08s
# 72:	learn: 1.3316520	test: 1.2681237	best: 1.2681237 (72)	total: 477ms	remaining: 6.06s
# 73:	learn: 1.3193429	test: 1.2556260	best: 1.2556260 (73)	total: 481ms	remaining: 6.02s
# 74:	learn: 1.3071070	test: 1.2431564	best: 1.2431564 (74)	total: 486ms	remaining: 5.99s
# 75:	learn: 1.2948281	test: 1.2303536	best: 1.2303536 (75)	total: 490ms	remaining: 5.96s
# 76:	learn: 1.2839083	test: 1.2186431	best: 1.2186431 (76)	total: 495ms	remaining: 5.93s
# 77:	learn: 1.2721437	test: 1.2059246	best: 1.2059246 (77)	total: 499ms	remaining: 5.89s
# 78:	learn: 1.2612674	test: 1.1945660	best: 1.1945660 (78)	total: 503ms	remaining: 5.87s
# 79:	learn: 1.2497708	test: 1.1824716	best: 1.1824716 (79)	total: 508ms	remaining: 5.84s
# 80:	learn: 1.2379362	test: 1.1704208	best: 1.1704208 (80)	total: 513ms	remaining: 5.82s
# 81:	learn: 1.2274484	test: 1.1593666	best: 1.1593666 (81)	total: 518ms	remaining: 5.8s
# 82:	learn: 1.2159145	test: 1.1475470	best: 1.1475470 (82)	total: 524ms	remaining: 5.79s
# 83:	learn: 1.2053434	test: 1.1368863	best: 1.1368863 (83)	total: 529ms	remaining: 5.77s
# 84:	learn: 1.1943194	test: 1.1251691	best: 1.1251691 (84)	total: 534ms	remaining: 5.75s
# 85:	learn: 1.1836349	test: 1.1142550	best: 1.1142550 (85)	total: 538ms	remaining: 5.72s
# 86:	learn: 1.1733493	test: 1.1035191	best: 1.1035191 (86)	total: 543ms	remaining: 5.7s
# 87:	learn: 1.1634046	test: 1.0933254	best: 1.0933254 (87)	total: 547ms	remaining: 5.67s
# 88:	learn: 1.1530080	test: 1.0826417	best: 1.0826417 (88)	total: 552ms	remaining: 5.65s
# 89:	learn: 1.1431229	test: 1.0720428	best: 1.0720428 (89)	total: 557ms	remaining: 5.63s
# 90:	learn: 1.1330723	test: 1.0616523	best: 1.0616523 (90)	total: 561ms	remaining: 5.6s
# 91:	learn: 1.1228272	test: 1.0508758	best: 1.0508758 (91)	total: 564ms	remaining: 5.56s
# 92:	learn: 1.1134586	test: 1.0409514	best: 1.0409514 (92)	total: 569ms	remaining: 5.54s
# 93:	learn: 1.1040427	test: 1.0308089	best: 1.0308089 (93)	total: 574ms	remaining: 5.53s
# 94:	learn: 1.0941575	test: 1.0206813	best: 1.0206813 (94)	total: 578ms	remaining: 5.51s
# 95:	learn: 1.0843413	test: 1.0103986	best: 1.0103986 (95)	total: 583ms	remaining: 5.49s
# 96:	learn: 1.0751210	test: 1.0007423	best: 1.0007423 (96)	total: 588ms	remaining: 5.47s
# 97:	learn: 1.0664556	test: 0.9913891	best: 0.9913891 (97)	total: 592ms	remaining: 5.45s
# 98:	learn: 1.0570594	test: 0.9812653	best: 0.9812653 (98)	total: 597ms	remaining: 5.43s
# 99:	learn: 1.0474744	test: 0.9716831	best: 0.9716831 (99)	total: 601ms	remaining: 5.41s
# 100:	learn: 1.0382717	test: 0.9623691	best: 0.9623691 (100)	total: 606ms	remaining: 5.4s
# 101:	learn: 1.0299932	test: 0.9535555	best: 0.9535555 (101)	total: 611ms	remaining: 5.38s
# 102:	learn: 1.0211669	test: 0.9445001	best: 0.9445001 (102)	total: 615ms	remaining: 5.36s
# 103:	learn: 1.0123097	test: 0.9355439	best: 0.9355439 (103)	total: 620ms	remaining: 5.34s
# 104:	learn: 1.0033326	test: 0.9264891	best: 0.9264891 (104)	total: 624ms	remaining: 5.32s
# 105:	learn: 0.9943210	test: 0.9173077	best: 0.9173077 (105)	total: 629ms	remaining: 5.3s
# 106:	learn: 0.9857147	test: 0.9085920	best: 0.9085920 (106)	total: 633ms	remaining: 5.28s
# 107:	learn: 0.9772331	test: 0.9000122	best: 0.9000122 (107)	total: 637ms	remaining: 5.26s
# 108:	learn: 0.9691395	test: 0.8912585	best: 0.8912585 (108)	total: 642ms	remaining: 5.25s
# 109:	learn: 0.9607420	test: 0.8826564	best: 0.8826564 (109)	total: 646ms	remaining: 5.23s
# 110:	learn: 0.9535306	test: 0.8751459	best: 0.8751459 (110)	total: 651ms	remaining: 5.21s
# 111:	learn: 0.9453960	test: 0.8665471	best: 0.8665471 (111)	total: 655ms	remaining: 5.19s
# 112:	learn: 0.9372152	test: 0.8582597	best: 0.8582597 (112)	total: 659ms	remaining: 5.18s
# 113:	learn: 0.9288620	test: 0.8498446	best: 0.8498446 (113)	total: 663ms	remaining: 5.16s
# 114:	learn: 0.9213643	test: 0.8424570	best: 0.8424570 (114)	total: 668ms	remaining: 5.14s
# 115:	learn: 0.9139528	test: 0.8348615	best: 0.8348615 (115)	total: 673ms	remaining: 5.13s
# 116:	learn: 0.9068696	test: 0.8278084	best: 0.8278084 (116)	total: 677ms	remaining: 5.11s
# 117:	learn: 0.8990723	test: 0.8199278	best: 0.8199278 (117)	total: 682ms	remaining: 5.09s
# 118:	learn: 0.8922839	test: 0.8131549	best: 0.8131549 (118)	total: 686ms	remaining: 5.08s
# 119:	learn: 0.8845194	test: 0.8052209	best: 0.8052209 (119)	total: 689ms	remaining: 5.05s
# 120:	learn: 0.8776404	test: 0.7976647	best: 0.7976647 (120)	total: 694ms	remaining: 5.04s
# 121:	learn: 0.8700359	test: 0.7898363	best: 0.7898363 (121)	total: 698ms	remaining: 5.03s
# 122:	learn: 0.8631588	test: 0.7827241	best: 0.7827241 (122)	total: 703ms	remaining: 5.01s
# 123:	learn: 0.8564550	test: 0.7754151	best: 0.7754151 (123)	total: 708ms	remaining: 5s
# 124:	learn: 0.8491299	test: 0.7680365	best: 0.7680365 (124)	total: 712ms	remaining: 4.98s
# 125:	learn: 0.8417915	test: 0.7606040	best: 0.7606040 (125)	total: 717ms	remaining: 4.97s
# 126:	learn: 0.8353043	test: 0.7535051	best: 0.7535051 (126)	total: 722ms	remaining: 4.96s
# 127:	learn: 0.8291360	test: 0.7468607	best: 0.7468607 (127)	total: 725ms	remaining: 4.94s
# 128:	learn: 0.8223807	test: 0.7399588	best: 0.7399588 (128)	total: 730ms	remaining: 4.93s
# 129:	learn: 0.8153753	test: 0.7329380	best: 0.7329380 (129)	total: 735ms	remaining: 4.92s
# 130:	learn: 0.8084330	test: 0.7260567	best: 0.7260567 (130)	total: 740ms	remaining: 4.91s
# 131:	learn: 0.8015776	test: 0.7191593	best: 0.7191593 (131)	total: 745ms	remaining: 4.9s
# 132:	learn: 0.7951894	test: 0.7126794	best: 0.7126794 (132)	total: 750ms	remaining: 4.88s
# 133:	learn: 0.7891370	test: 0.7060417	best: 0.7060417 (133)	total: 754ms	remaining: 4.87s
# 134:	learn: 0.7827450	test: 0.6996451	best: 0.6996451 (134)	total: 759ms	remaining: 4.86s
# 135:	learn: 0.7772429	test: 0.6934073	best: 0.6934073 (135)	total: 764ms	remaining: 4.85s
# 136:	learn: 0.7709685	test: 0.6870194	best: 0.6870194 (136)	total: 769ms	remaining: 4.84s
# 137:	learn: 0.7652610	test: 0.6810322	best: 0.6810322 (137)	total: 773ms	remaining: 4.83s
# 138:	learn: 0.7589084	test: 0.6745949	best: 0.6745949 (138)	total: 778ms	remaining: 4.82s
# 139:	learn: 0.7528646	test: 0.6685300	best: 0.6685300 (139)	total: 784ms	remaining: 4.82s
# 140:	learn: 0.7465979	test: 0.6623524	best: 0.6623524 (140)	total: 789ms	remaining: 4.81s
# 141:	learn: 0.7406642	test: 0.6565039	best: 0.6565039 (141)	total: 794ms	remaining: 4.8s
# 142:	learn: 0.7353584	test: 0.6509973	best: 0.6509973 (142)	total: 800ms	remaining: 4.79s
# 143:	learn: 0.7292592	test: 0.6448766	best: 0.6448766 (143)	total: 804ms	remaining: 4.78s
# 144:	learn: 0.7238637	test: 0.6395439	best: 0.6395439 (144)	total: 809ms	remaining: 4.77s
# 145:	learn: 0.7180538	test: 0.6337575	best: 0.6337575 (145)	total: 815ms	remaining: 4.77s
# 146:	learn: 0.7127396	test: 0.6285064	best: 0.6285064 (146)	total: 821ms	remaining: 4.76s
# 147:	learn: 0.7076797	test: 0.6228934	best: 0.6228934 (147)	total: 826ms	remaining: 4.75s
# 148:	learn: 0.7019673	test: 0.6172400	best: 0.6172400 (148)	total: 832ms	remaining: 4.75s
# 149:	learn: 0.6970182	test: 0.6121198	best: 0.6121198 (149)	total: 836ms	remaining: 4.74s
# 150:	learn: 0.6918433	test: 0.6066938	best: 0.6066938 (150)	total: 841ms	remaining: 4.73s
# 151:	learn: 0.6867549	test: 0.6013105	best: 0.6013105 (151)	total: 846ms	remaining: 4.72s
# 152:	learn: 0.6819636	test: 0.5966718	best: 0.5966718 (152)	total: 852ms	remaining: 4.72s
# 153:	learn: 0.6767066	test: 0.5914179	best: 0.5914179 (153)	total: 857ms	remaining: 4.71s
# 154:	learn: 0.6713656	test: 0.5861731	best: 0.5861731 (154)	total: 862ms	remaining: 4.7s
# 155:	learn: 0.6667842	test: 0.5812327	best: 0.5812327 (155)	total: 866ms	remaining: 4.68s
# 156:	learn: 0.6614773	test: 0.5760562	best: 0.5760562 (156)	total: 870ms	remaining: 4.67s
# 157:	learn: 0.6564397	test: 0.5710343	best: 0.5710343 (157)	total: 875ms	remaining: 4.66s
# 158:	learn: 0.6518255	test: 0.5663942	best: 0.5663942 (158)	total: 880ms	remaining: 4.65s
# 159:	learn: 0.6471625	test: 0.5615728	best: 0.5615728 (159)	total: 885ms	remaining: 4.64s
# 160:	learn: 0.6421891	test: 0.5566863	best: 0.5566863 (160)	total: 889ms	remaining: 4.63s
# 161:	learn: 0.6378661	test: 0.5521969	best: 0.5521969 (161)	total: 894ms	remaining: 4.63s
# 162:	learn: 0.6343521	test: 0.5483698	best: 0.5483698 (162)	total: 899ms	remaining: 4.61s
# 163:	learn: 0.6294234	test: 0.5435471	best: 0.5435471 (163)	total: 903ms	remaining: 4.61s
# 164:	learn: 0.6247266	test: 0.5390023	best: 0.5390023 (164)	total: 907ms	remaining: 4.59s
# 165:	learn: 0.6204581	test: 0.5344453	best: 0.5344453 (165)	total: 913ms	remaining: 4.58s
# 166:	learn: 0.6163862	test: 0.5301950	best: 0.5301950 (166)	total: 918ms	remaining: 4.58s
# 167:	learn: 0.6121059	test: 0.5257637	best: 0.5257637 (167)	total: 923ms	remaining: 4.57s
# 168:	learn: 0.6074335	test: 0.5212454	best: 0.5212454 (168)	total: 928ms	remaining: 4.56s
# 169:	learn: 0.6036415	test: 0.5176390	best: 0.5176390 (169)	total: 934ms	remaining: 4.56s
# 170:	learn: 0.5990945	test: 0.5131239	best: 0.5131239 (170)	total: 939ms	remaining: 4.55s
# 171:	learn: 0.5953219	test: 0.5090044	best: 0.5090044 (171)	total: 944ms	remaining: 4.54s
# 172:	learn: 0.5912774	test: 0.5049813	best: 0.5049813 (172)	total: 949ms	remaining: 4.54s
# 173:	learn: 0.5868771	test: 0.5007055	best: 0.5007055 (173)	total: 954ms	remaining: 4.53s
# 174:	learn: 0.5825915	test: 0.4964668	best: 0.4964668 (174)	total: 958ms	remaining: 4.52s
# 175:	learn: 0.5783138	test: 0.4924068	best: 0.4924068 (175)	total: 963ms	remaining: 4.51s
# 176:	learn: 0.5741519	test: 0.4884339	best: 0.4884339 (176)	total: 969ms	remaining: 4.5s
# 177:	learn: 0.5702691	test: 0.4846629	best: 0.4846629 (177)	total: 973ms	remaining: 4.49s
# 178:	learn: 0.5660633	test: 0.4806073	best: 0.4806073 (178)	total: 977ms	remaining: 4.48s
# 179:	learn: 0.5628418	test: 0.4772736	best: 0.4772736 (179)	total: 982ms	remaining: 4.47s
# 180:	learn: 0.5594357	test: 0.4734886	best: 0.4734886 (180)	total: 986ms	remaining: 4.46s
# 181:	learn: 0.5563056	test: 0.4701066	best: 0.4701066 (181)	total: 990ms	remaining: 4.45s
# 182:	learn: 0.5527770	test: 0.4668147	best: 0.4668147 (182)	total: 995ms	remaining: 4.44s
# 183:	learn: 0.5494673	test: 0.4633960	best: 0.4633960 (183)	total: 1s	remaining: 4.43s
# 184:	learn: 0.5455447	test: 0.4595637	best: 0.4595637 (184)	total: 1s	remaining: 4.42s
# 185:	learn: 0.5421542	test: 0.4560896	best: 0.4560896 (185)	total: 1.01s	remaining: 4.42s
# 186:	learn: 0.5386148	test: 0.4525292	best: 0.4525292 (186)	total: 1.01s	remaining: 4.41s
# 187:	learn: 0.5354282	test: 0.4490424	best: 0.4490424 (187)	total: 1.02s	remaining: 4.41s
# 188:	learn: 0.5322286	test: 0.4456742	best: 0.4456742 (188)	total: 1.03s	remaining: 4.4s
# 189:	learn: 0.5285715	test: 0.4423058	best: 0.4423058 (189)	total: 1.03s	remaining: 4.4s
# 190:	learn: 0.5252737	test: 0.4389552	best: 0.4389552 (190)	total: 1.03s	remaining: 4.39s
# 191:	learn: 0.5220118	test: 0.4356258	best: 0.4356258 (191)	total: 1.04s	remaining: 4.38s
# 192:	learn: 0.5187187	test: 0.4322749	best: 0.4322749 (192)	total: 1.04s	remaining: 4.37s
# 193:	learn: 0.5157237	test: 0.4292218	best: 0.4292218 (193)	total: 1.05s	remaining: 4.36s
# 194:	learn: 0.5121153	test: 0.4257392	best: 0.4257392 (194)	total: 1.05s	remaining: 4.36s
# 195:	learn: 0.5089931	test: 0.4230460	best: 0.4230460 (195)	total: 1.06s	remaining: 4.36s
# 196:	learn: 0.5058083	test: 0.4200954	best: 0.4200954 (196)	total: 1.07s	remaining: 4.35s
# 197:	learn: 0.5029588	test: 0.4169789	best: 0.4169789 (197)	total: 1.07s	remaining: 4.35s
# 198:	learn: 0.4996250	test: 0.4139068	best: 0.4139068 (198)	total: 1.08s	remaining: 4.34s
# 199:	learn: 0.4965324	test: 0.4111703	best: 0.4111703 (199)	total: 1.08s	remaining: 4.33s
# 200:	learn: 0.4938237	test: 0.4084231	best: 0.4084231 (200)	total: 1.09s	remaining: 4.33s
# 201:	learn: 0.4908177	test: 0.4053360	best: 0.4053360 (201)	total: 1.09s	remaining: 4.32s
# 202:	learn: 0.4880995	test: 0.4025150	best: 0.4025150 (202)	total: 1.1s	remaining: 4.31s
# 203:	learn: 0.4851990	test: 0.3999231	best: 0.3999231 (203)	total: 1.1s	remaining: 4.3s
# 204:	learn: 0.4820434	test: 0.3969987	best: 0.3969987 (204)	total: 1.11s	remaining: 4.3s
# 205:	learn: 0.4791161	test: 0.3946135	best: 0.3946135 (205)	total: 1.11s	remaining: 4.29s
# 206:	learn: 0.4759601	test: 0.3917264	best: 0.3917264 (206)	total: 1.12s	remaining: 4.28s
# 207:	learn: 0.4736802	test: 0.3890861	best: 0.3890861 (207)	total: 1.12s	remaining: 4.28s
# 208:	learn: 0.4708252	test: 0.3864849	best: 0.3864849 (208)	total: 1.13s	remaining: 4.27s
# 209:	learn: 0.4679929	test: 0.3839162	best: 0.3839162 (209)	total: 1.13s	remaining: 4.26s
# 210:	learn: 0.4650193	test: 0.3812435	best: 0.3812435 (210)	total: 1.14s	remaining: 4.26s
# 211:	learn: 0.4624842	test: 0.3791506	best: 0.3791506 (211)	total: 1.14s	remaining: 4.25s
# 212:	learn: 0.4599117	test: 0.3765936	best: 0.3765936 (212)	total: 1.15s	remaining: 4.24s
# 213:	learn: 0.4576144	test: 0.3743484	best: 0.3743484 (213)	total: 1.15s	remaining: 4.23s
# 214:	learn: 0.4548377	test: 0.3720890	best: 0.3720890 (214)	total: 1.16s	remaining: 4.23s
# 215:	learn: 0.4522113	test: 0.3698049	best: 0.3698049 (215)	total: 1.16s	remaining: 4.22s
# 216:	learn: 0.4496765	test: 0.3676217	best: 0.3676217 (216)	total: 1.17s	remaining: 4.21s
# 217:	learn: 0.4470664	test: 0.3652033	best: 0.3652033 (217)	total: 1.17s	remaining: 4.2s
# 218:	learn: 0.4444248	test: 0.3628798	best: 0.3628798 (218)	total: 1.18s	remaining: 4.2s
# 219:	learn: 0.4418494	test: 0.3608947	best: 0.3608947 (219)	total: 1.18s	remaining: 4.19s
# 220:	learn: 0.4393674	test: 0.3591853	best: 0.3591853 (220)	total: 1.19s	remaining: 4.18s
# 221:	learn: 0.4370468	test: 0.3569351	best: 0.3569351 (221)	total: 1.19s	remaining: 4.17s
# 222:	learn: 0.4343572	test: 0.3545807	best: 0.3545807 (222)	total: 1.2s	remaining: 4.16s
# 223:	learn: 0.4319504	test: 0.3524625	best: 0.3524625 (223)	total: 1.2s	remaining: 4.16s
# 224:	learn: 0.4296584	test: 0.3505999	best: 0.3505999 (224)	total: 1.2s	remaining: 4.15s
# 225:	learn: 0.4274824	test: 0.3482970	best: 0.3482970 (225)	total: 1.21s	remaining: 4.14s
# 226:	learn: 0.4250620	test: 0.3461946	best: 0.3461946 (226)	total: 1.21s	remaining: 4.13s
# 227:	learn: 0.4226550	test: 0.3442201	best: 0.3442201 (227)	total: 1.22s	remaining: 4.13s
# 228:	learn: 0.4201393	test: 0.3420018	best: 0.3420018 (228)	total: 1.22s	remaining: 4.12s
# 229:	learn: 0.4176842	test: 0.3399890	best: 0.3399890 (229)	total: 1.23s	remaining: 4.11s
# 230:	learn: 0.4155649	test: 0.3381502	best: 0.3381502 (230)	total: 1.23s	remaining: 4.1s
# 231:	learn: 0.4134450	test: 0.3361877	best: 0.3361877 (231)	total: 1.24s	remaining: 4.1s
# 232:	learn: 0.4111836	test: 0.3342873	best: 0.3342873 (232)	total: 1.24s	remaining: 4.09s
# 233:	learn: 0.4086308	test: 0.3323208	best: 0.3323208 (233)	total: 1.25s	remaining: 4.08s
# 234:	learn: 0.4060866	test: 0.3300293	best: 0.3300293 (234)	total: 1.25s	remaining: 4.08s
# 235:	learn: 0.4042083	test: 0.3282886	best: 0.3282886 (235)	total: 1.26s	remaining: 4.07s
# 236:	learn: 0.4018645	test: 0.3265142	best: 0.3265142 (236)	total: 1.26s	remaining: 4.06s
# 237:	learn: 0.3995538	test: 0.3246642	best: 0.3246642 (237)	total: 1.26s	remaining: 4.05s
# 238:	learn: 0.3979519	test: 0.3239038	best: 0.3239038 (238)	total: 1.27s	remaining: 4.04s
# 239:	learn: 0.3961183	test: 0.3221813	best: 0.3221813 (239)	total: 1.27s	remaining: 4.04s
# 240:	learn: 0.3944052	test: 0.3206296	best: 0.3206296 (240)	total: 1.28s	remaining: 4.03s
# 241:	learn: 0.3923836	test: 0.3187195	best: 0.3187195 (241)	total: 1.28s	remaining: 4.03s
# 242:	learn: 0.3901624	test: 0.3169078	best: 0.3169078 (242)	total: 1.29s	remaining: 4.02s
# 243:	learn: 0.3879461	test: 0.3150889	best: 0.3150889 (243)	total: 1.29s	remaining: 4.01s
# 244:	learn: 0.3859960	test: 0.3134849	best: 0.3134849 (244)	total: 1.3s	remaining: 4.01s
# 245:	learn: 0.3842405	test: 0.3118055	best: 0.3118055 (245)	total: 1.3s	remaining: 4s
# 246:	learn: 0.3820535	test: 0.3104416	best: 0.3104416 (246)	total: 1.31s	remaining: 3.99s
# 247:	learn: 0.3800125	test: 0.3086676	best: 0.3086676 (247)	total: 1.31s	remaining: 3.98s
# 248:	learn: 0.3778197	test: 0.3071838	best: 0.3071838 (248)	total: 1.32s	remaining: 3.98s
# 249:	learn: 0.3757648	test: 0.3057327	best: 0.3057327 (249)	total: 1.32s	remaining: 3.97s
# 250:	learn: 0.3738583	test: 0.3042293	best: 0.3042293 (250)	total: 1.33s	remaining: 3.96s
# 251:	learn: 0.3720348	test: 0.3028974	best: 0.3028974 (251)	total: 1.33s	remaining: 3.96s
# 252:	learn: 0.3701304	test: 0.3016201	best: 0.3016201 (252)	total: 1.34s	remaining: 3.95s
# 253:	learn: 0.3686698	test: 0.3003056	best: 0.3003056 (253)	total: 1.34s	remaining: 3.94s
# 254:	learn: 0.3670029	test: 0.2993916	best: 0.2993916 (254)	total: 1.35s	remaining: 3.94s
# 255:	learn: 0.3653228	test: 0.2980775	best: 0.2980775 (255)	total: 1.35s	remaining: 3.93s
# 256:	learn: 0.3634662	test: 0.2967156	best: 0.2967156 (256)	total: 1.36s	remaining: 3.92s
# 257:	learn: 0.3615355	test: 0.2952543	best: 0.2952543 (257)	total: 1.36s	remaining: 3.91s
# 258:	learn: 0.3600604	test: 0.2943469	best: 0.2943469 (258)	total: 1.36s	remaining: 3.91s
# 259:	learn: 0.3584406	test: 0.2929323	best: 0.2929323 (259)	total: 1.37s	remaining: 3.9s
# 260:	learn: 0.3566166	test: 0.2916212	best: 0.2916212 (260)	total: 1.38s	remaining: 3.9s
# 261:	learn: 0.3549284	test: 0.2903748	best: 0.2903748 (261)	total: 1.38s	remaining: 3.9s
# 262:	learn: 0.3534651	test: 0.2891705	best: 0.2891705 (262)	total: 1.39s	remaining: 3.89s
# 263:	learn: 0.3519761	test: 0.2879031	best: 0.2879031 (263)	total: 1.39s	remaining: 3.88s
# 264:	learn: 0.3501348	test: 0.2866806	best: 0.2866806 (264)	total: 1.4s	remaining: 3.87s
# 265:	learn: 0.3484573	test: 0.2854686	best: 0.2854686 (265)	total: 1.4s	remaining: 3.87s
# 266:	learn: 0.3471108	test: 0.2841503	best: 0.2841503 (266)	total: 1.41s	remaining: 3.86s
# 267:	learn: 0.3456042	test: 0.2830971	best: 0.2830971 (267)	total: 1.41s	remaining: 3.85s
# 268:	learn: 0.3440182	test: 0.2818644	best: 0.2818644 (268)	total: 1.42s	remaining: 3.85s
# 269:	learn: 0.3425818	test: 0.2806694	best: 0.2806694 (269)	total: 1.42s	remaining: 3.84s
# 270:	learn: 0.3413249	test: 0.2802590	best: 0.2802590 (270)	total: 1.43s	remaining: 3.84s
# 271:	learn: 0.3395824	test: 0.2791120	best: 0.2791120 (271)	total: 1.43s	remaining: 3.83s
# 272:	learn: 0.3381786	test: 0.2779663	best: 0.2779663 (272)	total: 1.43s	remaining: 3.82s
# 273:	learn: 0.3365789	test: 0.2768103	best: 0.2768103 (273)	total: 1.44s	remaining: 3.81s
# 274:	learn: 0.3350641	test: 0.2757477	best: 0.2757477 (274)	total: 1.44s	remaining: 3.81s
# 275:	learn: 0.3333958	test: 0.2747698	best: 0.2747698 (275)	total: 1.45s	remaining: 3.8s
# 276:	learn: 0.3317324	test: 0.2737158	best: 0.2737158 (276)	total: 1.45s	remaining: 3.79s
# 277:	learn: 0.3300693	test: 0.2725833	best: 0.2725833 (277)	total: 1.46s	remaining: 3.78s
# 278:	learn: 0.3288661	test: 0.2717702	best: 0.2717702 (278)	total: 1.46s	remaining: 3.78s
# 279:	learn: 0.3272879	test: 0.2707138	best: 0.2707138 (279)	total: 1.47s	remaining: 3.77s
# 280:	learn: 0.3256596	test: 0.2697380	best: 0.2697380 (280)	total: 1.47s	remaining: 3.76s
# 281:	learn: 0.3240764	test: 0.2685775	best: 0.2685775 (281)	total: 1.47s	remaining: 3.75s
# 282:	learn: 0.3226961	test: 0.2676449	best: 0.2676449 (282)	total: 1.48s	remaining: 3.74s
# 283:	learn: 0.3211777	test: 0.2667970	best: 0.2667970 (283)	total: 1.48s	remaining: 3.74s
# 284:	learn: 0.3195405	test: 0.2657976	best: 0.2657976 (284)	total: 1.49s	remaining: 3.73s
# 285:	learn: 0.3179787	test: 0.2649376	best: 0.2649376 (285)	total: 1.49s	remaining: 3.72s
# 286:	learn: 0.3165195	test: 0.2639910	best: 0.2639910 (286)	total: 1.5s	remaining: 3.72s
# 287:	learn: 0.3150779	test: 0.2629582	best: 0.2629582 (287)	total: 1.5s	remaining: 3.71s
# 288:	learn: 0.3135946	test: 0.2618755	best: 0.2618755 (288)	total: 1.5s	remaining: 3.7s
# 289:	learn: 0.3121414	test: 0.2608465	best: 0.2608465 (289)	total: 1.51s	remaining: 3.69s
# 290:	learn: 0.3111990	test: 0.2600279	best: 0.2600279 (290)	total: 1.51s	remaining: 3.69s
# 291:	learn: 0.3102049	test: 0.2596730	best: 0.2596730 (291)	total: 1.52s	remaining: 3.68s
# 292:	learn: 0.3089753	test: 0.2586769	best: 0.2586769 (292)	total: 1.52s	remaining: 3.67s
# 293:	learn: 0.3078223	test: 0.2577663	best: 0.2577663 (293)	total: 1.53s	remaining: 3.67s
# 294:	learn: 0.3063379	test: 0.2569372	best: 0.2569372 (294)	total: 1.53s	remaining: 3.66s
# 295:	learn: 0.3048929	test: 0.2560843	best: 0.2560843 (295)	total: 1.54s	remaining: 3.66s
# 296:	learn: 0.3034280	test: 0.2552191	best: 0.2552191 (296)	total: 1.54s	remaining: 3.65s
# 297:	learn: 0.3019920	test: 0.2541865	best: 0.2541865 (297)	total: 1.55s	remaining: 3.65s
# 298:	learn: 0.3009750	test: 0.2533583	best: 0.2533583 (298)	total: 1.55s	remaining: 3.64s
# 299:	learn: 0.2995919	test: 0.2525689	best: 0.2525689 (299)	total: 1.56s	remaining: 3.63s
# 300:	learn: 0.2986368	test: 0.2519841	best: 0.2519841 (300)	total: 1.56s	remaining: 3.63s
# 301:	learn: 0.2973124	test: 0.2511306	best: 0.2511306 (301)	total: 1.56s	remaining: 3.62s
# 302:	learn: 0.2959734	test: 0.2503553	best: 0.2503553 (302)	total: 1.57s	remaining: 3.61s
# 303:	learn: 0.2947606	test: 0.2496043	best: 0.2496043 (303)	total: 1.57s	remaining: 3.6s
# 304:	learn: 0.2933322	test: 0.2489139	best: 0.2489139 (304)	total: 1.58s	remaining: 3.6s
# 305:	learn: 0.2919535	test: 0.2483023	best: 0.2483023 (305)	total: 1.58s	remaining: 3.59s
# 306:	learn: 0.2906029	test: 0.2475775	best: 0.2475775 (306)	total: 1.59s	remaining: 3.59s
# 307:	learn: 0.2891912	test: 0.2469660	best: 0.2469660 (307)	total: 1.59s	remaining: 3.58s
# 308:	learn: 0.2878356	test: 0.2459328	best: 0.2459328 (308)	total: 1.6s	remaining: 3.57s
# 309:	learn: 0.2866283	test: 0.2456038	best: 0.2456038 (309)	total: 1.6s	remaining: 3.56s
# 310:	learn: 0.2855071	test: 0.2449878	best: 0.2449878 (310)	total: 1.61s	remaining: 3.56s
# 311:	learn: 0.2843637	test: 0.2444965	best: 0.2444965 (311)	total: 1.61s	remaining: 3.55s
# 312:	learn: 0.2830475	test: 0.2435436	best: 0.2435436 (312)	total: 1.61s	remaining: 3.54s
# 313:	learn: 0.2821224	test: 0.2428997	best: 0.2428997 (313)	total: 1.62s	remaining: 3.54s
# 314:	learn: 0.2809578	test: 0.2423669	best: 0.2423669 (314)	total: 1.62s	remaining: 3.53s
# 315:	learn: 0.2798047	test: 0.2416877	best: 0.2416877 (315)	total: 1.63s	remaining: 3.52s
# 316:	learn: 0.2786613	test: 0.2412542	best: 0.2412542 (316)	total: 1.63s	remaining: 3.52s
# 317:	learn: 0.2774880	test: 0.2405518	best: 0.2405518 (317)	total: 1.64s	remaining: 3.51s
# 318:	learn: 0.2767183	test: 0.2399231	best: 0.2399231 (318)	total: 1.64s	remaining: 3.51s
# 319:	learn: 0.2760003	test: 0.2393244	best: 0.2393244 (319)	total: 1.65s	remaining: 3.5s
# 320:	learn: 0.2750523	test: 0.2389441	best: 0.2389441 (320)	total: 1.65s	remaining: 3.5s
# 321:	learn: 0.2739421	test: 0.2384005	best: 0.2384005 (321)	total: 1.66s	remaining: 3.49s
# 322:	learn: 0.2728496	test: 0.2378236	best: 0.2378236 (322)	total: 1.66s	remaining: 3.48s
# 323:	learn: 0.2719447	test: 0.2372192	best: 0.2372192 (323)	total: 1.67s	remaining: 3.48s
# 324:	learn: 0.2707970	test: 0.2367058	best: 0.2367058 (324)	total: 1.67s	remaining: 3.47s
# 325:	learn: 0.2698879	test: 0.2363872	best: 0.2363872 (325)	total: 1.67s	remaining: 3.46s
# 326:	learn: 0.2690904	test: 0.2360816	best: 0.2360816 (326)	total: 1.68s	remaining: 3.46s
# 327:	learn: 0.2681061	test: 0.2356894	best: 0.2356894 (327)	total: 1.68s	remaining: 3.45s
# 328:	learn: 0.2669108	test: 0.2348381	best: 0.2348381 (328)	total: 1.69s	remaining: 3.44s
# 329:	learn: 0.2658802	test: 0.2344535	best: 0.2344535 (329)	total: 1.69s	remaining: 3.43s
# 330:	learn: 0.2647784	test: 0.2339504	best: 0.2339504 (330)	total: 1.7s	remaining: 3.43s
# 331:	learn: 0.2639267	test: 0.2333768	best: 0.2333768 (331)	total: 1.7s	remaining: 3.42s
# 332:	learn: 0.2631403	test: 0.2328715	best: 0.2328715 (332)	total: 1.71s	remaining: 3.42s
# 333:	learn: 0.2621475	test: 0.2324030	best: 0.2324030 (333)	total: 1.71s	remaining: 3.41s
# 334:	learn: 0.2610951	test: 0.2319484	best: 0.2319484 (334)	total: 1.71s	remaining: 3.4s
# 335:	learn: 0.2603796	test: 0.2315803	best: 0.2315803 (335)	total: 1.72s	remaining: 3.4s
# 336:	learn: 0.2595909	test: 0.2314919	best: 0.2314919 (336)	total: 1.72s	remaining: 3.39s
# 337:	learn: 0.2585465	test: 0.2308054	best: 0.2308054 (337)	total: 1.73s	remaining: 3.39s
# 338:	learn: 0.2574998	test: 0.2304059	best: 0.2304059 (338)	total: 1.73s	remaining: 3.38s
# 339:	learn: 0.2564860	test: 0.2300148	best: 0.2300148 (339)	total: 1.74s	remaining: 3.37s
# 340:	learn: 0.2557795	test: 0.2296117	best: 0.2296117 (340)	total: 1.74s	remaining: 3.37s
# 341:	learn: 0.2546963	test: 0.2288806	best: 0.2288806 (341)	total: 1.75s	remaining: 3.36s
# 342:	learn: 0.2539370	test: 0.2284623	best: 0.2284623 (342)	total: 1.75s	remaining: 3.35s
# 343:	learn: 0.2528267	test: 0.2281295	best: 0.2281295 (343)	total: 1.75s	remaining: 3.35s
# 344:	learn: 0.2517220	test: 0.2277726	best: 0.2277726 (344)	total: 1.76s	remaining: 3.34s
# 345:	learn: 0.2508039	test: 0.2273831	best: 0.2273831 (345)	total: 1.76s	remaining: 3.33s
# 346:	learn: 0.2498841	test: 0.2270341	best: 0.2270341 (346)	total: 1.77s	remaining: 3.33s
# 347:	learn: 0.2489463	test: 0.2266121	best: 0.2266121 (347)	total: 1.77s	remaining: 3.32s
# 348:	learn: 0.2481909	test: 0.2262605	best: 0.2262605 (348)	total: 1.78s	remaining: 3.32s
# 349:	learn: 0.2476068	test: 0.2258424	best: 0.2258424 (349)	total: 1.78s	remaining: 3.31s
# 350:	learn: 0.2466612	test: 0.2253886	best: 0.2253886 (350)	total: 1.79s	remaining: 3.31s
# 351:	learn: 0.2456969	test: 0.2250308	best: 0.2250308 (351)	total: 1.79s	remaining: 3.3s
# 352:	learn: 0.2446285	test: 0.2243205	best: 0.2243205 (352)	total: 1.8s	remaining: 3.29s
# 353:	learn: 0.2441197	test: 0.2239648	best: 0.2239648 (353)	total: 1.8s	remaining: 3.29s
# 354:	learn: 0.2435531	test: 0.2236387	best: 0.2236387 (354)	total: 1.81s	remaining: 3.28s
# 355:	learn: 0.2425715	test: 0.2230415	best: 0.2230415 (355)	total: 1.81s	remaining: 3.28s
# 356:	learn: 0.2420085	test: 0.2227163	best: 0.2227163 (356)	total: 1.82s	remaining: 3.27s
# 357:	learn: 0.2409839	test: 0.2219525	best: 0.2219525 (357)	total: 1.82s	remaining: 3.27s
# 358:	learn: 0.2400621	test: 0.2214123	best: 0.2214123 (358)	total: 1.82s	remaining: 3.26s
# 359:	learn: 0.2391752	test: 0.2209876	best: 0.2209876 (359)	total: 1.83s	remaining: 3.25s
# 360:	learn: 0.2384178	test: 0.2206617	best: 0.2206617 (360)	total: 1.83s	remaining: 3.25s
# 361:	learn: 0.2375215	test: 0.2203328	best: 0.2203328 (361)	total: 1.84s	remaining: 3.24s
# 362:	learn: 0.2366381	test: 0.2199785	best: 0.2199785 (362)	total: 1.84s	remaining: 3.24s
# 363:	learn: 0.2358886	test: 0.2196694	best: 0.2196694 (363)	total: 1.85s	remaining: 3.23s
# 364:	learn: 0.2351092	test: 0.2193914	best: 0.2193914 (364)	total: 1.85s	remaining: 3.22s
# 365:	learn: 0.2343805	test: 0.2191310	best: 0.2191310 (365)	total: 1.86s	remaining: 3.21s
# 366:	learn: 0.2337603	test: 0.2187887	best: 0.2187887 (366)	total: 1.86s	remaining: 3.21s
# 367:	learn: 0.2327844	test: 0.2185443	best: 0.2185443 (367)	total: 1.86s	remaining: 3.2s
# 368:	learn: 0.2322559	test: 0.2182489	best: 0.2182489 (368)	total: 1.87s	remaining: 3.2s
# 369:	learn: 0.2312992	test: 0.2181848	best: 0.2181848 (369)	total: 1.87s	remaining: 3.19s
# 370:	learn: 0.2306185	test: 0.2179120	best: 0.2179120 (370)	total: 1.88s	remaining: 3.18s
# 371:	learn: 0.2298562	test: 0.2176682	best: 0.2176682 (371)	total: 1.88s	remaining: 3.18s
# 372:	learn: 0.2289791	test: 0.2173606	best: 0.2173606 (372)	total: 1.89s	remaining: 3.17s
# 373:	learn: 0.2283960	test: 0.2171217	best: 0.2171217 (373)	total: 1.89s	remaining: 3.17s
# 374:	learn: 0.2276713	test: 0.2171330	best: 0.2171217 (373)	total: 1.9s	remaining: 3.16s
# 375:	learn: 0.2268818	test: 0.2166861	best: 0.2166861 (375)	total: 1.9s	remaining: 3.15s
# 376:	learn: 0.2261390	test: 0.2164498	best: 0.2164498 (376)	total: 1.91s	remaining: 3.15s
# 377:	learn: 0.2254095	test: 0.2161692	best: 0.2161692 (377)	total: 1.91s	remaining: 3.14s
# 378:	learn: 0.2244332	test: 0.2160391	best: 0.2160391 (378)	total: 1.91s	remaining: 3.14s
# 379:	learn: 0.2238944	test: 0.2158229	best: 0.2158229 (379)	total: 1.92s	remaining: 3.13s
# 380:	learn: 0.2230862	test: 0.2155407	best: 0.2155407 (380)	total: 1.93s	remaining: 3.13s
# 381:	learn: 0.2221540	test: 0.2154509	best: 0.2154509 (381)	total: 1.93s	remaining: 3.12s
# 382:	learn: 0.2213639	test: 0.2153829	best: 0.2153829 (382)	total: 1.94s	remaining: 3.12s
# 383:	learn: 0.2207026	test: 0.2152454	best: 0.2152454 (383)	total: 1.94s	remaining: 3.11s
# 384:	learn: 0.2202425	test: 0.2150034	best: 0.2150034 (384)	total: 1.95s	remaining: 3.11s
# 385:	learn: 0.2197917	test: 0.2147981	best: 0.2147981 (385)	total: 1.95s	remaining: 3.1s
# 386:	learn: 0.2191658	test: 0.2147839	best: 0.2147839 (386)	total: 1.96s	remaining: 3.1s
# 387:	learn: 0.2188274	test: 0.2144784	best: 0.2144784 (387)	total: 1.96s	remaining: 3.09s
# 388:	learn: 0.2181667	test: 0.2142599	best: 0.2142599 (388)	total: 1.97s	remaining: 3.09s
# 389:	learn: 0.2176882	test: 0.2139931	best: 0.2139931 (389)	total: 1.97s	remaining: 3.08s
# 390:	learn: 0.2169822	test: 0.2138311	best: 0.2138311 (390)	total: 1.98s	remaining: 3.08s
# 391:	learn: 0.2163598	test: 0.2137033	best: 0.2137033 (391)	total: 1.98s	remaining: 3.07s
# 392:	learn: 0.2156554	test: 0.2135530	best: 0.2135530 (392)	total: 1.99s	remaining: 3.07s
# 393:	learn: 0.2151241	test: 0.2133358	best: 0.2133358 (393)	total: 1.99s	remaining: 3.06s
# 394:	learn: 0.2142155	test: 0.2128088	best: 0.2128088 (394)	total: 2s	remaining: 3.06s
# 395:	learn: 0.2134634	test: 0.2125402	best: 0.2125402 (395)	total: 2s	remaining: 3.05s
# 396:	learn: 0.2127284	test: 0.2124956	best: 0.2124956 (396)	total: 2s	remaining: 3.04s
# 397:	learn: 0.2119323	test: 0.2122903	best: 0.2122903 (397)	total: 2.01s	remaining: 3.04s
# 398:	learn: 0.2112825	test: 0.2120865	best: 0.2120865 (398)	total: 2.01s	remaining: 3.03s
# 399:	learn: 0.2105396	test: 0.2119074	best: 0.2119074 (399)	total: 2.02s	remaining: 3.03s
# 400:	learn: 0.2098545	test: 0.2118524	best: 0.2118524 (400)	total: 2.03s	remaining: 3.04s
# 401:	learn: 0.2091669	test: 0.2116745	best: 0.2116745 (401)	total: 2.04s	remaining: 3.03s
# 402:	learn: 0.2085738	test: 0.2114512	best: 0.2114512 (402)	total: 2.04s	remaining: 3.02s
# 403:	learn: 0.2079449	test: 0.2112918	best: 0.2112918 (403)	total: 2.05s	remaining: 3.02s
# 404:	learn: 0.2073447	test: 0.2111419	best: 0.2111419 (404)	total: 2.05s	remaining: 3.02s
# 405:	learn: 0.2066250	test: 0.2110054	best: 0.2110054 (405)	total: 2.06s	remaining: 3.01s
# 406:	learn: 0.2060371	test: 0.2110141	best: 0.2110054 (405)	total: 2.06s	remaining: 3s
# 407:	learn: 0.2052057	test: 0.2108307	best: 0.2108307 (407)	total: 2.07s	remaining: 3s
# 408:	learn: 0.2044308	test: 0.2106973	best: 0.2106973 (408)	total: 2.07s	remaining: 2.99s
# 409:	learn: 0.2039556	test: 0.2105246	best: 0.2105246 (409)	total: 2.07s	remaining: 2.98s
# 410:	learn: 0.2032334	test: 0.2104882	best: 0.2104882 (410)	total: 2.08s	remaining: 2.98s
# 411:	learn: 0.2027769	test: 0.2102991	best: 0.2102991 (411)	total: 2.08s	remaining: 2.97s
# 412:	learn: 0.2024321	test: 0.2102642	best: 0.2102642 (412)	total: 2.09s	remaining: 2.96s
# 413:	learn: 0.2018294	test: 0.2101076	best: 0.2101076 (413)	total: 2.09s	remaining: 2.96s
# 414:	learn: 0.2013967	test: 0.2099642	best: 0.2099642 (414)	total: 2.1s	remaining: 2.95s
# 415:	learn: 0.2008377	test: 0.2098041	best: 0.2098041 (415)	total: 2.1s	remaining: 2.95s
# 416:	learn: 0.2001185	test: 0.2096319	best: 0.2096319 (416)	total: 2.1s	remaining: 2.94s
# 417:	learn: 0.1995613	test: 0.2094468	best: 0.2094468 (417)	total: 2.11s	remaining: 2.94s
# 418:	learn: 0.1990309	test: 0.2093769	best: 0.2093769 (418)	total: 2.12s	remaining: 2.93s
# 419:	learn: 0.1982663	test: 0.2090831	best: 0.2090831 (419)	total: 2.12s	remaining: 2.93s
# 420:	learn: 0.1977259	test: 0.2090970	best: 0.2090831 (419)	total: 2.13s	remaining: 2.92s
# 421:	learn: 0.1971885	test: 0.2089385	best: 0.2089385 (421)	total: 2.13s	remaining: 2.92s
# 422:	learn: 0.1965403	test: 0.2088415	best: 0.2088415 (422)	total: 2.13s	remaining: 2.91s
# 423:	learn: 0.1959125	test: 0.2087513	best: 0.2087513 (423)	total: 2.14s	remaining: 2.9s
# 424:	learn: 0.1952105	test: 0.2086169	best: 0.2086169 (424)	total: 2.14s	remaining: 2.9s
# 425:	learn: 0.1945553	test: 0.2085873	best: 0.2085873 (425)	total: 2.15s	remaining: 2.89s
# 426:	learn: 0.1939745	test: 0.2084751	best: 0.2084751 (426)	total: 2.15s	remaining: 2.89s
# 427:	learn: 0.1936988	test: 0.2084293	best: 0.2084293 (427)	total: 2.15s	remaining: 2.88s
# 428:	learn: 0.1930471	test: 0.2082676	best: 0.2082676 (428)	total: 2.16s	remaining: 2.87s
# 429:	learn: 0.1924661	test: 0.2081783	best: 0.2081783 (429)	total: 2.16s	remaining: 2.87s
# 430:	learn: 0.1921778	test: 0.2080016	best: 0.2080016 (430)	total: 2.17s	remaining: 2.86s
# 431:	learn: 0.1915972	test: 0.2078454	best: 0.2078454 (431)	total: 2.17s	remaining: 2.86s
# 432:	learn: 0.1910886	test: 0.2077267	best: 0.2077267 (432)	total: 2.18s	remaining: 2.85s
# 433:	learn: 0.1904963	test: 0.2075745	best: 0.2075745 (433)	total: 2.18s	remaining: 2.85s
# 434:	learn: 0.1899744	test: 0.2073867	best: 0.2073867 (434)	total: 2.19s	remaining: 2.84s
# 435:	learn: 0.1895948	test: 0.2072056	best: 0.2072056 (435)	total: 2.19s	remaining: 2.84s
# 436:	learn: 0.1892448	test: 0.2070919	best: 0.2070919 (436)	total: 2.2s	remaining: 2.83s
# 437:	learn: 0.1887327	test: 0.2069515	best: 0.2069515 (437)	total: 2.2s	remaining: 2.83s
# 438:	learn: 0.1881827	test: 0.2069088	best: 0.2069088 (438)	total: 2.21s	remaining: 2.82s
# 439:	learn: 0.1878113	test: 0.2069803	best: 0.2069088 (438)	total: 2.21s	remaining: 2.81s
# 440:	learn: 0.1872174	test: 0.2068959	best: 0.2068959 (440)	total: 2.21s	remaining: 2.81s
# 441:	learn: 0.1867829	test: 0.2067523	best: 0.2067523 (441)	total: 2.22s	remaining: 2.8s
# 442:	learn: 0.1862731	test: 0.2066723	best: 0.2066723 (442)	total: 2.22s	remaining: 2.8s
# 443:	learn: 0.1860011	test: 0.2065214	best: 0.2065214 (443)	total: 2.23s	remaining: 2.79s
# 444:	learn: 0.1854048	test: 0.2064881	best: 0.2064881 (444)	total: 2.23s	remaining: 2.79s
# 445:	learn: 0.1848912	test: 0.2063538	best: 0.2063538 (445)	total: 2.24s	remaining: 2.78s
# 446:	learn: 0.1843391	test: 0.2064248	best: 0.2063538 (445)	total: 2.24s	remaining: 2.77s
# 447:	learn: 0.1839682	test: 0.2062597	best: 0.2062597 (447)	total: 2.25s	remaining: 2.77s
# 448:	learn: 0.1834457	test: 0.2064129	best: 0.2062597 (447)	total: 2.25s	remaining: 2.76s
# 449:	learn: 0.1828881	test: 0.2062436	best: 0.2062436 (449)	total: 2.25s	remaining: 2.75s
# 450:	learn: 0.1825162	test: 0.2060718	best: 0.2060718 (450)	total: 2.26s	remaining: 2.75s
# 451:	learn: 0.1821194	test: 0.2060599	best: 0.2060599 (451)	total: 2.26s	remaining: 2.74s
# 452:	learn: 0.1817712	test: 0.2059477	best: 0.2059477 (452)	total: 2.27s	remaining: 2.74s
# 453:	learn: 0.1816734	test: 0.2059424	best: 0.2059424 (453)	total: 2.27s	remaining: 2.73s
# 454:	learn: 0.1812306	test: 0.2058026	best: 0.2058026 (454)	total: 2.28s	remaining: 2.73s
# 455:	learn: 0.1809505	test: 0.2056329	best: 0.2056329 (455)	total: 2.28s	remaining: 2.72s
# 456:	learn: 0.1805671	test: 0.2055216	best: 0.2055216 (456)	total: 2.29s	remaining: 2.72s
# 457:	learn: 0.1801504	test: 0.2054177	best: 0.2054177 (457)	total: 2.29s	remaining: 2.71s
# 458:	learn: 0.1796176	test: 0.2053156	best: 0.2053156 (458)	total: 2.3s	remaining: 2.71s
# 459:	learn: 0.1790982	test: 0.2051726	best: 0.2051726 (459)	total: 2.3s	remaining: 2.7s
# 460:	learn: 0.1787717	test: 0.2051253	best: 0.2051253 (460)	total: 2.31s	remaining: 2.69s
# 461:	learn: 0.1784673	test: 0.2051226	best: 0.2051226 (461)	total: 2.31s	remaining: 2.69s
# 462:	learn: 0.1781300	test: 0.2051617	best: 0.2051226 (461)	total: 2.31s	remaining: 2.68s
# 463:	learn: 0.1777983	test: 0.2050818	best: 0.2050818 (463)	total: 2.32s	remaining: 2.68s
# 464:	learn: 0.1773450	test: 0.2051428	best: 0.2050818 (463)	total: 2.33s	remaining: 2.67s
# 465:	learn: 0.1770848	test: 0.2050263	best: 0.2050263 (465)	total: 2.33s	remaining: 2.67s
# 466:	learn: 0.1767658	test: 0.2049184	best: 0.2049184 (466)	total: 2.33s	remaining: 2.66s
# 467:	learn: 0.1761967	test: 0.2049236	best: 0.2049184 (466)	total: 2.34s	remaining: 2.66s
# 468:	learn: 0.1759951	test: 0.2049049	best: 0.2049049 (468)	total: 2.34s	remaining: 2.65s
# 469:	learn: 0.1755519	test: 0.2047473	best: 0.2047473 (469)	total: 2.35s	remaining: 2.65s
# 470:	learn: 0.1750140	test: 0.2046827	best: 0.2046827 (470)	total: 2.35s	remaining: 2.64s
# 471:	learn: 0.1745407	test: 0.2046758	best: 0.2046758 (471)	total: 2.36s	remaining: 2.64s
# 472:	learn: 0.1742382	test: 0.2046461	best: 0.2046461 (472)	total: 2.36s	remaining: 2.63s
# 473:	learn: 0.1737999	test: 0.2046392	best: 0.2046392 (473)	total: 2.37s	remaining: 2.63s
# 474:	learn: 0.1735437	test: 0.2044861	best: 0.2044861 (474)	total: 2.37s	remaining: 2.62s
# 475:	learn: 0.1733895	test: 0.2043580	best: 0.2043580 (475)	total: 2.38s	remaining: 2.62s
# 476:	learn: 0.1730094	test: 0.2042676	best: 0.2042676 (476)	total: 2.38s	remaining: 2.61s
# 477:	learn: 0.1724337	test: 0.2041678	best: 0.2041678 (477)	total: 2.38s	remaining: 2.6s
# 478:	learn: 0.1718129	test: 0.2039377	best: 0.2039377 (478)	total: 2.39s	remaining: 2.6s
# 479:	learn: 0.1712288	test: 0.2037093	best: 0.2037093 (479)	total: 2.39s	remaining: 2.59s
# 480:	learn: 0.1707695	test: 0.2035984	best: 0.2035984 (480)	total: 2.4s	remaining: 2.59s
# 481:	learn: 0.1702494	test: 0.2036321	best: 0.2035984 (480)	total: 2.4s	remaining: 2.58s
# 482:	learn: 0.1699991	test: 0.2036205	best: 0.2035984 (480)	total: 2.41s	remaining: 2.58s
# 483:	learn: 0.1695737	test: 0.2035608	best: 0.2035608 (483)	total: 2.41s	remaining: 2.57s
# 484:	learn: 0.1690646	test: 0.2035278	best: 0.2035278 (484)	total: 2.42s	remaining: 2.56s
# 485:	learn: 0.1684026	test: 0.2034429	best: 0.2034429 (485)	total: 2.42s	remaining: 2.56s
# 486:	learn: 0.1679852	test: 0.2034073	best: 0.2034073 (486)	total: 2.42s	remaining: 2.55s
# 487:	learn: 0.1675051	test: 0.2033009	best: 0.2033009 (487)	total: 2.43s	remaining: 2.55s
# 488:	learn: 0.1671222	test: 0.2031765	best: 0.2031765 (488)	total: 2.43s	remaining: 2.54s
# 489:	learn: 0.1666753	test: 0.2031346	best: 0.2031346 (489)	total: 2.44s	remaining: 2.54s
# 490:	learn: 0.1661196	test: 0.2030877	best: 0.2030877 (490)	total: 2.44s	remaining: 2.53s
# 491:	learn: 0.1657229	test: 0.2029793	best: 0.2029793 (491)	total: 2.45s	remaining: 2.53s
# 492:	learn: 0.1651598	test: 0.2029263	best: 0.2029263 (492)	total: 2.45s	remaining: 2.52s
# 493:	learn: 0.1649142	test: 0.2028356	best: 0.2028356 (493)	total: 2.46s	remaining: 2.52s
# 494:	learn: 0.1644924	test: 0.2027724	best: 0.2027724 (494)	total: 2.46s	remaining: 2.51s
# 495:	learn: 0.1640925	test: 0.2027043	best: 0.2027043 (495)	total: 2.46s	remaining: 2.5s
# 496:	learn: 0.1636612	test: 0.2026627	best: 0.2026627 (496)	total: 2.47s	remaining: 2.5s
# 497:	learn: 0.1631826	test: 0.2026677	best: 0.2026627 (496)	total: 2.47s	remaining: 2.49s
# 498:	learn: 0.1627275	test: 0.2026321	best: 0.2026321 (498)	total: 2.48s	remaining: 2.49s
# 499:	learn: 0.1624646	test: 0.2026686	best: 0.2026321 (498)	total: 2.48s	remaining: 2.48s
# 500:	learn: 0.1622363	test: 0.2025684	best: 0.2025684 (500)	total: 2.49s	remaining: 2.48s
# 501:	learn: 0.1618996	test: 0.2025843	best: 0.2025684 (500)	total: 2.49s	remaining: 2.47s
# 502:	learn: 0.1616512	test: 0.2025224	best: 0.2025224 (502)	total: 2.5s	remaining: 2.46s
# 503:	learn: 0.1614126	test: 0.2024392	best: 0.2024392 (503)	total: 2.5s	remaining: 2.46s
# 504:	learn: 0.1611374	test: 0.2025042	best: 0.2024392 (503)	total: 2.5s	remaining: 2.46s
# 505:	learn: 0.1607340	test: 0.2023382	best: 0.2023382 (505)	total: 2.51s	remaining: 2.45s
# 506:	learn: 0.1603771	test: 0.2023073	best: 0.2023073 (506)	total: 2.51s	remaining: 2.44s
# 507:	learn: 0.1599379	test: 0.2022837	best: 0.2022837 (507)	total: 2.52s	remaining: 2.44s
# 508:	learn: 0.1596888	test: 0.2022162	best: 0.2022162 (508)	total: 2.53s	remaining: 2.44s
# 509:	learn: 0.1594511	test: 0.2021405	best: 0.2021405 (509)	total: 2.53s	remaining: 2.43s
# 510:	learn: 0.1589613	test: 0.2021042	best: 0.2021042 (510)	total: 2.53s	remaining: 2.42s
# 511:	learn: 0.1585997	test: 0.2022500	best: 0.2021042 (510)	total: 2.54s	remaining: 2.42s
# 512:	learn: 0.1583029	test: 0.2021781	best: 0.2021042 (510)	total: 2.54s	remaining: 2.41s
# 513:	learn: 0.1578559	test: 0.2021531	best: 0.2021042 (510)	total: 2.55s	remaining: 2.41s
# 514:	learn: 0.1574604	test: 0.2020824	best: 0.2020824 (514)	total: 2.55s	remaining: 2.4s
# 515:	learn: 0.1572321	test: 0.2020052	best: 0.2020052 (515)	total: 2.56s	remaining: 2.4s
# 516:	learn: 0.1570443	test: 0.2019147	best: 0.2019147 (516)	total: 2.56s	remaining: 2.39s
# 517:	learn: 0.1566081	test: 0.2018773	best: 0.2018773 (517)	total: 2.57s	remaining: 2.39s
# 518:	learn: 0.1563501	test: 0.2018814	best: 0.2018773 (517)	total: 2.57s	remaining: 2.38s
# 519:	learn: 0.1561359	test: 0.2017996	best: 0.2017996 (519)	total: 2.58s	remaining: 2.38s
# 520:	learn: 0.1556117	test: 0.2017965	best: 0.2017965 (520)	total: 2.58s	remaining: 2.37s
# 521:	learn: 0.1553045	test: 0.2017099	best: 0.2017099 (521)	total: 2.59s	remaining: 2.37s
# 522:	learn: 0.1549998	test: 0.2017259	best: 0.2017099 (521)	total: 2.59s	remaining: 2.36s
# 523:	learn: 0.1547738	test: 0.2016926	best: 0.2016926 (523)	total: 2.6s	remaining: 2.36s
# 524:	learn: 0.1542981	test: 0.2015537	best: 0.2015537 (524)	total: 2.6s	remaining: 2.35s
# 525:	learn: 0.1540186	test: 0.2015752	best: 0.2015537 (524)	total: 2.61s	remaining: 2.35s
# 526:	learn: 0.1537078	test: 0.2015386	best: 0.2015386 (526)	total: 2.61s	remaining: 2.34s
# 527:	learn: 0.1533815	test: 0.2014776	best: 0.2014776 (527)	total: 2.62s	remaining: 2.34s
# 528:	learn: 0.1531684	test: 0.2014439	best: 0.2014439 (528)	total: 2.62s	remaining: 2.33s
# 529:	learn: 0.1529883	test: 0.2013842	best: 0.2013842 (529)	total: 2.63s	remaining: 2.33s
# 530:	learn: 0.1526568	test: 0.2012715	best: 0.2012715 (530)	total: 2.63s	remaining: 2.32s
# 531:	learn: 0.1523755	test: 0.2012751	best: 0.2012715 (530)	total: 2.63s	remaining: 2.32s
# 532:	learn: 0.1519471	test: 0.2010096	best: 0.2010096 (532)	total: 2.64s	remaining: 2.31s
# 533:	learn: 0.1516142	test: 0.2009487	best: 0.2009487 (533)	total: 2.65s	remaining: 2.31s
# 534:	learn: 0.1512715	test: 0.2009062	best: 0.2009062 (534)	total: 2.65s	remaining: 2.3s
# 535:	learn: 0.1509370	test: 0.2008485	best: 0.2008485 (535)	total: 2.65s	remaining: 2.3s
# 536:	learn: 0.1507290	test: 0.2008341	best: 0.2008341 (536)	total: 2.66s	remaining: 2.29s
# ...
# 681:	learn: 0.1567425	test: 0.5937822	best: 0.5937822 (681)	total: 3.25s	remaining: 1.52s
# 682:	learn: 0.1566390	test: 0.5934342	best: 0.5934342 (682)	total: 3.26s	remaining: 1.51s
# 683:	learn: 0.1563351	test: 0.5934197	best: 0.5934197 (683)	total: 3.26s	remaining: 1.51s
# 684:	learn: 0.1562265	test: 0.5934064	best: 0.5934064 (684)	total: 3.27s	remaining: 1.5s
# 685:	learn: 0.1559382	test: 0.5933556	best: 0.5933556 (685)	total: 3.27s	remaining: 1.5s
# 686:	learn: 0.1557712	test: 0.5930035	best: 0.5930035 (686)	total: 3.28s	remaining: 1.49s
# 687:	learn: 0.1556018	test: 0.5926517	best: 0.5926517 (687)	total: 3.28s	remaining: 1.49s
# 688:	learn: 0.1555112	test: 0.5926402	best: 0.5926402 (688)	total: 3.29s	remaining: 1.48s
# 689:	learn: 0.1553365	test: 0.5926338	best: 0.5926338 (689)	total: 3.29s	remaining: 1.48s
# 690:	learn: 0.1552542	test: 0.5923701	best: 0.5923701 (690)	total: 3.3s	remaining: 1.47s
# 691:	learn: 0.1549430	test: 0.5923811	best: 0.5923701 (690)	total: 3.3s	remaining: 1.47s
# 692:	learn: 0.1548191	test: 0.5920356	best: 0.5920356 (692)	total: 3.31s	remaining: 1.47s
# 693:	learn: 0.1546435	test: 0.5916913	best: 0.5916913 (693)	total: 3.31s	remaining: 1.46s
# 694:	learn: 0.1545434	test: 0.5916862	best: 0.5916862 (694)	total: 3.32s	remaining: 1.46s
# 695:	learn: 0.1544302	test: 0.5917234	best: 0.5916862 (694)	total: 3.32s	remaining: 1.45s
# 696:	learn: 0.1543188	test: 0.5913891	best: 0.5913891 (696)	total: 3.33s	remaining: 1.45s
# 697:	learn: 0.1542046	test: 0.5910510	best: 0.5910510 (697)	total: 3.33s	remaining: 1.44s
# 698:	learn: 0.1540919	test: 0.5910855	best: 0.5910510 (697)	total: 3.34s	remaining: 1.44s
# 699:	learn: 0.1538111	test: 0.5910961	best: 0.5910510 (697)	total: 3.34s	remaining: 1.43s
# 700:	learn: 0.1534427	test: 0.5907613	best: 0.5907613 (700)	total: 3.35s	remaining: 1.43s
# 701:	learn: 0.1530964	test: 0.5907595	best: 0.5907595 (701)	total: 3.35s	remaining: 1.42s
# 702:	learn: 0.1530075	test: 0.5907488	best: 0.5907488 (702)	total: 3.36s	remaining: 1.42s
# 703:	learn: 0.1529154	test: 0.5907304	best: 0.5907304 (703)	total: 3.36s	remaining: 1.41s
# 704:	learn: 0.1528235	test: 0.5907146	best: 0.5907146 (704)	total: 3.37s	remaining: 1.41s
# 705:	learn: 0.1525624	test: 0.5903590	best: 0.5903590 (705)	total: 3.37s	remaining: 1.4s
# 706:	learn: 0.1524195	test: 0.5903489	best: 0.5903489 (706)	total: 3.38s	remaining: 1.4s
# 707:	learn: 0.1522867	test: 0.5903438	best: 0.5903438 (707)	total: 3.38s	remaining: 1.4s
# 708:	learn: 0.1521957	test: 0.5903274	best: 0.5903274 (708)	total: 3.39s	remaining: 1.39s
# 709:	learn: 0.1521248	test: 0.5903195	best: 0.5903195 (709)	total: 3.4s	remaining: 1.39s
# 710:	learn: 0.1520378	test: 0.5903127	best: 0.5903127 (710)	total: 3.4s	remaining: 1.38s
# 711:	learn: 0.1519345	test: 0.5903175	best: 0.5903127 (710)	total: 3.41s	remaining: 1.38s
# 712:	learn: 0.1516494	test: 0.5903237	best: 0.5903127 (710)	total: 3.41s	remaining: 1.37s
# 713:	learn: 0.1515537	test: 0.5903070	best: 0.5903070 (713)	total: 3.42s	remaining: 1.37s
# 714:	learn: 0.1511289	test: 0.5903072	best: 0.5903070 (713)	total: 3.42s	remaining: 1.36s
# 715:	learn: 0.1507642	test: 0.5903160	best: 0.5903070 (713)	total: 3.43s	remaining: 1.36s
# 716:	learn: 0.1506088	test: 0.5903535	best: 0.5903070 (713)	total: 3.43s	remaining: 1.35s
# 717:	learn: 0.1504643	test: 0.5903537	best: 0.5903070 (713)	total: 3.44s	remaining: 1.35s
# 718:	learn: 0.1501156	test: 0.5900582	best: 0.5900582 (718)	total: 3.44s	remaining: 1.34s
# 719:	learn: 0.1499692	test: 0.5900357	best: 0.5900357 (719)	total: 3.45s	remaining: 1.34s
# 720:	learn: 0.1498886	test: 0.5900221	best: 0.5900221 (720)	total: 3.45s	remaining: 1.34s
# 721:	learn: 0.1496778	test: 0.5896751	best: 0.5896751 (721)	total: 3.46s	remaining: 1.33s
# 722:	learn: 0.1494048	test: 0.5893222	best: 0.5893222 (722)	total: 3.46s	remaining: 1.33s
# 723:	learn: 0.1493091	test: 0.5893618	best: 0.5893222 (722)	total: 3.47s	remaining: 1.32s
# 724:	learn: 0.1492158	test: 0.5893550	best: 0.5893222 (722)	total: 3.47s	remaining: 1.32s
# 725:	learn: 0.1489881	test: 0.5890424	best: 0.5890424 (725)	total: 3.48s	remaining: 1.31s
# 726:	learn: 0.1488965	test: 0.5890313	best: 0.5890313 (726)	total: 3.48s	remaining: 1.31s
# 727:	learn: 0.1487975	test: 0.5890672	best: 0.5890313 (726)	total: 3.49s	remaining: 1.3s
# 728:	learn: 0.1487242	test: 0.5890600	best: 0.5890313 (726)	total: 3.49s	remaining: 1.3s
# 729:	learn: 0.1485258	test: 0.5890606	best: 0.5890313 (726)	total: 3.5s	remaining: 1.29s
# 730:	learn: 0.1484448	test: 0.5888244	best: 0.5888244 (730)	total: 3.5s	remaining: 1.29s
# 731:	learn: 0.1483599	test: 0.5888131	best: 0.5888131 (731)	total: 3.5s	remaining: 1.28s
# 732:	learn: 0.1480980	test: 0.5888238	best: 0.5888131 (731)	total: 3.51s	remaining: 1.28s
# 733:	learn: 0.1479700	test: 0.5885242	best: 0.5885242 (733)	total: 3.51s	remaining: 1.27s
# 734:	learn: 0.1475372	test: 0.5882227	best: 0.5882227 (734)	total: 3.52s	remaining: 1.27s
# 735:	learn: 0.1474752	test: 0.5880419	best: 0.5880419 (735)	total: 3.52s	remaining: 1.26s
# 736:	learn: 0.1473403	test: 0.5880355	best: 0.5880355 (736)	total: 3.53s	remaining: 1.26s
# 737:	learn: 0.1472581	test: 0.5880240	best: 0.5880240 (737)	total: 3.54s	remaining: 1.25s
# 738:	learn: 0.1471713	test: 0.5880453	best: 0.5880240 (737)	total: 3.54s	remaining: 1.25s
# 739:	learn: 0.1470912	test: 0.5880310	best: 0.5880240 (737)	total: 3.54s	remaining: 1.25s
# 740:	learn: 0.1469951	test: 0.5880064	best: 0.5880064 (740)	total: 3.55s	remaining: 1.24s
# 741:	learn: 0.1467406	test: 0.5880141	best: 0.5880064 (740)	total: 3.55s	remaining: 1.24s
# 742:	learn: 0.1466252	test: 0.5877237	best: 0.5877237 (742)	total: 3.56s	remaining: 1.23s
# 743:	learn: 0.1463639	test: 0.5877185	best: 0.5877185 (743)	total: 3.56s	remaining: 1.23s
# 744:	learn: 0.1462726	test: 0.5877038	best: 0.5877038 (744)	total: 3.57s	remaining: 1.22s
# 745:	learn: 0.1461558	test: 0.5876805	best: 0.5876805 (745)	total: 3.58s	remaining: 1.22s
# 746:	learn: 0.1459980	test: 0.5876813	best: 0.5876805 (745)	total: 3.58s	remaining: 1.21s
# 747:	learn: 0.1458961	test: 0.5876742	best: 0.5876742 (747)	total: 3.59s	remaining: 1.21s
# 748:	learn: 0.1457561	test: 0.5876770	best: 0.5876742 (747)	total: 3.6s	remaining: 1.21s
# 749:	learn: 0.1456802	test: 0.5876734	best: 0.5876734 (749)	total: 3.6s	remaining: 1.2s
# 750:	learn: 0.1455270	test: 0.5876684	best: 0.5876684 (750)	total: 3.61s	remaining: 1.2s
# 751:	learn: 0.1453906	test: 0.5876740	best: 0.5876684 (750)	total: 3.62s	remaining: 1.19s
# 752:	learn: 0.1450873	test: 0.5876783	best: 0.5876684 (750)	total: 3.62s	remaining: 1.19s
# 753:	learn: 0.1450209	test: 0.5874602	best: 0.5874602 (753)	total: 3.63s	remaining: 1.18s
# 754:	learn: 0.1449536	test: 0.5874464	best: 0.5874464 (754)	total: 3.63s	remaining: 1.18s
# 755:	learn: 0.1446968	test: 0.5871557	best: 0.5871557 (755)	total: 3.63s	remaining: 1.17s
# 756:	learn: 0.1443800	test: 0.5871671	best: 0.5871557 (755)	total: 3.64s	remaining: 1.17s
# 757:	learn: 0.1441430	test: 0.5871977	best: 0.5871557 (755)	total: 3.64s	remaining: 1.16s
# 758:	learn: 0.1440586	test: 0.5871850	best: 0.5871557 (755)	total: 3.65s	remaining: 1.16s
# 759:	learn: 0.1439817	test: 0.5871733	best: 0.5871557 (755)	total: 3.65s	remaining: 1.15s
# 760:	learn: 0.1438542	test: 0.5871579	best: 0.5871557 (755)	total: 3.66s	remaining: 1.15s
# 761:	learn: 0.1435236	test: 0.5871611	best: 0.5871557 (755)	total: 3.66s	remaining: 1.14s
# 762:	learn: 0.1433045	test: 0.5870759	best: 0.5870759 (762)	total: 3.67s	remaining: 1.14s
# 763:	learn: 0.1432422	test: 0.5870661	best: 0.5870661 (763)	total: 3.67s	remaining: 1.14s
# 764:	learn: 0.1431139	test: 0.5870607	best: 0.5870607 (764)	total: 3.68s	remaining: 1.13s
# 765:	learn: 0.1428649	test: 0.5870564	best: 0.5870564 (765)	total: 3.69s	remaining: 1.13s
# 766:	learn: 0.1425554	test: 0.5870619	best: 0.5870564 (765)	total: 3.69s	remaining: 1.12s
# 767:	learn: 0.1424253	test: 0.5867820	best: 0.5867820 (767)	total: 3.7s	remaining: 1.12s
# 768:	learn: 0.1421900	test: 0.5867617	best: 0.5867617 (768)	total: 3.71s	remaining: 1.11s
# 769:	learn: 0.1420703	test: 0.5867216	best: 0.5867216 (769)	total: 3.71s	remaining: 1.11s
# 770:	learn: 0.1419899	test: 0.5867196	best: 0.5867196 (770)	total: 3.72s	remaining: 1.1s
# 771:	learn: 0.1418684	test: 0.5867220	best: 0.5867196 (770)	total: 3.72s	remaining: 1.1s
# 772:	learn: 0.1417515	test: 0.5867053	best: 0.5867053 (772)	total: 3.73s	remaining: 1.09s
# 773:	learn: 0.1416779	test: 0.5866968	best: 0.5866968 (773)	total: 3.73s	remaining: 1.09s
# 774:	learn: 0.1416008	test: 0.5866794	best: 0.5866794 (774)	total: 3.73s	remaining: 1.08s
# 775:	learn: 0.1415473	test: 0.5866766	best: 0.5866766 (775)	total: 3.74s	remaining: 1.08s
# 776:	learn: 0.1413092	test: 0.5866903	best: 0.5866766 (775)	total: 3.75s	remaining: 1.07s
# 777:	learn: 0.1412248	test: 0.5866884	best: 0.5866766 (775)	total: 3.75s	remaining: 1.07s
# 778:	learn: 0.1411419	test: 0.5866794	best: 0.5866766 (775)	total: 3.75s	remaining: 1.06s
# 779:	learn: 0.1410615	test: 0.5866839	best: 0.5866766 (775)	total: 3.76s	remaining: 1.06s
# 780:	learn: 0.1407517	test: 0.5866674	best: 0.5866674 (780)	total: 3.76s	remaining: 1.05s
# 781:	learn: 0.1406833	test: 0.5866546	best: 0.5866546 (781)	total: 3.77s	remaining: 1.05s
# 782:	learn: 0.1404835	test: 0.5866441	best: 0.5866441 (782)	total: 3.77s	remaining: 1.04s
# 783:	learn: 0.1404138	test: 0.5866270	best: 0.5866270 (783)	total: 3.78s	remaining: 1.04s
# 784:	learn: 0.1401727	test: 0.5866200	best: 0.5866200 (784)	total: 3.78s	remaining: 1.03s
# 785:	learn: 0.1399390	test: 0.5863624	best: 0.5863624 (785)	total: 3.79s	remaining: 1.03s
# 786:	learn: 0.1398777	test: 0.5863561	best: 0.5863561 (786)	total: 3.79s	remaining: 1.03s
# 787:	learn: 0.1397596	test: 0.5863512	best: 0.5863512 (787)	total: 3.8s	remaining: 1.02s
# 788:	learn: 0.1394324	test: 0.5861268	best: 0.5861268 (788)	total: 3.8s	remaining: 1.02s
# 789:	learn: 0.1391538	test: 0.5858835	best: 0.5858835 (789)	total: 3.81s	remaining: 1.01s
# 790:	learn: 0.1391190	test: 0.5858619	best: 0.5858619 (790)	total: 3.81s	remaining: 1.01s
# 791:	learn: 0.1388932	test: 0.5858350	best: 0.5858350 (791)	total: 3.81s	remaining: 1s
# 792:	learn: 0.1385741	test: 0.5855837	best: 0.5855837 (792)	total: 3.82s	remaining: 997ms
# 793:	learn: 0.1385048	test: 0.5856218	best: 0.5855837 (792)	total: 3.82s	remaining: 992ms
# 794:	learn: 0.1384563	test: 0.5856181	best: 0.5855837 (792)	total: 3.83s	remaining: 988ms
# 795:	learn: 0.1382155	test: 0.5856132	best: 0.5855837 (792)	total: 3.83s	remaining: 983ms
# 796:	learn: 0.1380966	test: 0.5856076	best: 0.5855837 (792)	total: 3.84s	remaining: 978ms
# 797:	learn: 0.1378701	test: 0.5853545	best: 0.5853545 (797)	total: 3.84s	remaining: 973ms
# 798:	learn: 0.1377943	test: 0.5853796	best: 0.5853545 (797)	total: 3.85s	remaining: 968ms
# 799:	learn: 0.1377388	test: 0.5853745	best: 0.5853545 (797)	total: 3.85s	remaining: 963ms
# 800:	learn: 0.1376302	test: 0.5853504	best: 0.5853504 (800)	total: 3.86s	remaining: 958ms
# 801:	learn: 0.1374022	test: 0.5853783	best: 0.5853504 (800)	total: 3.86s	remaining: 953ms
# 802:	learn: 0.1373128	test: 0.5854176	best: 0.5853504 (800)	total: 3.87s	remaining: 948ms
# 803:	learn: 0.1371520	test: 0.5854392	best: 0.5853504 (800)	total: 3.87s	remaining: 944ms
# 804:	learn: 0.1370519	test: 0.5851865	best: 0.5851865 (804)	total: 3.87s	remaining: 939ms
# 805:	learn: 0.1367607	test: 0.5849774	best: 0.5849774 (805)	total: 3.88s	remaining: 933ms
# 806:	learn: 0.1364130	test: 0.5849440	best: 0.5849440 (806)	total: 3.88s	remaining: 928ms
# 807:	learn: 0.1363504	test: 0.5849425	best: 0.5849425 (807)	total: 3.89s	remaining: 924ms
# 808:	learn: 0.1361258	test: 0.5847013	best: 0.5847013 (808)	total: 3.89s	remaining: 919ms
# 809:	learn: 0.1360794	test: 0.5846940	best: 0.5846940 (809)	total: 3.9s	remaining: 914ms
# 810:	learn: 0.1359125	test: 0.5844271	best: 0.5844271 (810)	total: 3.9s	remaining: 909ms
# 811:	learn: 0.1358446	test: 0.5841804	best: 0.5841804 (811)	total: 3.91s	remaining: 905ms
# 812:	learn: 0.1354898	test: 0.5839382	best: 0.5839382 (812)	total: 3.91s	remaining: 900ms
# 813:	learn: 0.1354307	test: 0.5839404	best: 0.5839382 (812)	total: 3.92s	remaining: 895ms
# 814:	learn: 0.1353851	test: 0.5839319	best: 0.5839319 (814)	total: 3.92s	remaining: 890ms
# 815:	learn: 0.1351847	test: 0.5839322	best: 0.5839319 (814)	total: 3.92s	remaining: 885ms
# 816:	learn: 0.1350562	test: 0.5839315	best: 0.5839315 (816)	total: 3.93s	remaining: 880ms
# 817:	learn: 0.1350067	test: 0.5839227	best: 0.5839227 (817)	total: 3.93s	remaining: 875ms
# 818:	learn: 0.1349008	test: 0.5839058	best: 0.5839058 (818)	total: 3.94s	remaining: 871ms
# 819:	learn: 0.1348488	test: 0.5839062	best: 0.5839058 (818)	total: 3.94s	remaining: 866ms
# 820:	learn: 0.1346927	test: 0.5839172	best: 0.5839058 (818)	total: 3.95s	remaining: 861ms
# 821:	learn: 0.1346456	test: 0.5839132	best: 0.5839058 (818)	total: 3.95s	remaining: 856ms
# 822:	learn: 0.1345786	test: 0.5838602	best: 0.5838602 (822)	total: 3.96s	remaining: 851ms
# 823:	learn: 0.1344552	test: 0.5836183	best: 0.5836183 (823)	total: 3.96s	remaining: 846ms
# 824:	learn: 0.1344350	test: 0.5836119	best: 0.5836119 (824)	total: 3.96s	remaining: 841ms
# 825:	learn: 0.1341485	test: 0.5836304	best: 0.5836119 (824)	total: 3.97s	remaining: 836ms
# 826:	learn: 0.1340732	test: 0.5836274	best: 0.5836119 (824)	total: 3.97s	remaining: 831ms
# 827:	learn: 0.1338982	test: 0.5836404	best: 0.5836119 (824)	total: 3.98s	remaining: 826ms
# 828:	learn: 0.1338301	test: 0.5834017	best: 0.5834017 (828)	total: 3.98s	remaining: 821ms
# 829:	learn: 0.1337521	test: 0.5834141	best: 0.5834017 (828)	total: 3.99s	remaining: 817ms
# 830:	learn: 0.1334726	test: 0.5834331	best: 0.5834017 (828)	total: 3.99s	remaining: 812ms
# 831:	learn: 0.1334098	test: 0.5831933	best: 0.5831933 (831)	total: 4s	remaining: 807ms
# 832:	learn: 0.1331423	test: 0.5829670	best: 0.5829670 (832)	total: 4s	remaining: 802ms
# 833:	learn: 0.1329374	test: 0.5829803	best: 0.5829670 (832)	total: 4s	remaining: 797ms
# 834:	learn: 0.1328792	test: 0.5829693	best: 0.5829670 (832)	total: 4.01s	remaining: 792ms
# 835:	learn: 0.1326563	test: 0.5829644	best: 0.5829644 (835)	total: 4.01s	remaining: 787ms
# 836:	learn: 0.1324420	test: 0.5829680	best: 0.5829644 (835)	total: 4.02s	remaining: 783ms
# 837:	learn: 0.1323179	test: 0.5827373	best: 0.5827373 (837)	total: 4.02s	remaining: 778ms
# 838:	learn: 0.1319676	test: 0.5825089	best: 0.5825089 (838)	total: 4.03s	remaining: 773ms
# 839:	learn: 0.1318600	test: 0.5824990	best: 0.5824990 (839)	total: 4.03s	remaining: 768ms
# 840:	learn: 0.1318192	test: 0.5824969	best: 0.5824969 (840)	total: 4.04s	remaining: 764ms
# 841:	learn: 0.1316919	test: 0.5822674	best: 0.5822674 (841)	total: 4.04s	remaining: 759ms
# 842:	learn: 0.1314226	test: 0.5822622	best: 0.5822622 (842)	total: 4.05s	remaining: 754ms
# 843:	learn: 0.1312430	test: 0.5822425	best: 0.5822425 (843)	total: 4.05s	remaining: 749ms
# 844:	learn: 0.1312028	test: 0.5822475	best: 0.5822425 (843)	total: 4.06s	remaining: 744ms
# 845:	learn: 0.1308624	test: 0.5820366	best: 0.5820366 (845)	total: 4.06s	remaining: 740ms
# 846:	learn: 0.1308044	test: 0.5820290	best: 0.5820290 (846)	total: 4.07s	remaining: 735ms
# 847:	learn: 0.1307424	test: 0.5820541	best: 0.5820290 (846)	total: 4.07s	remaining: 730ms
# 848:	learn: 0.1305326	test: 0.5820491	best: 0.5820290 (846)	total: 4.08s	remaining: 725ms
# 849:	learn: 0.1304874	test: 0.5820422	best: 0.5820290 (846)	total: 4.08s	remaining: 721ms
# 850:	learn: 0.1304266	test: 0.5820748	best: 0.5820290 (846)	total: 4.09s	remaining: 716ms
# 851:	learn: 0.1303295	test: 0.5820706	best: 0.5820290 (846)	total: 4.09s	remaining: 711ms
# 852:	learn: 0.1303057	test: 0.5820639	best: 0.5820290 (846)	total: 4.1s	remaining: 706ms
# 853:	learn: 0.1301823	test: 0.5820632	best: 0.5820290 (846)	total: 4.1s	remaining: 702ms
# 854:	learn: 0.1301446	test: 0.5820597	best: 0.5820290 (846)	total: 4.11s	remaining: 697ms
# 855:	learn: 0.1300872	test: 0.5820539	best: 0.5820290 (846)	total: 4.11s	remaining: 692ms
# 856:	learn: 0.1298410	test: 0.5820567	best: 0.5820290 (846)	total: 4.12s	remaining: 688ms
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.5820290402
# bestIteration = 846
#
# Shrink model to first 847 iterations.
# Overall R^2 (CatBoostRegressor): 0.9843745980713882

# %%
from lightgbm import LGBMRegressor

n_splits =5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Parametere derived from here https://www.kaggle.com/code/thiagomantuani/ps4e5-flood-prediction-get-started
# One can get this using optuna, gris, random or baysein technique as well which will take time
#https://www.kaggle.com/code/harshitstark/regression-with-a-flood-prediction-dataset/notebook

lgb_params = {
    'boosting_type': 'gbdt', 
    'n_estimators':1500, 
    'learning_rate' :  0.012,    
    'num_leaves' : 250, 
    'subsample_for_bin': 165700, 
    'min_child_samples': 114, 
    'reg_alpha': 2.075e-06, 
    'reg_lambda': 3.839e-07, 
    'colsample_bytree': 0.9634,
    'subsample': 0.9592, 
    'max_depth': 10,
    'random_state':0,
    'verbosity':-1}

lgbm_predictions = np.zeros(len(scaled_train_data))
lgbm_true_labels = np.zeros(len(scaled_train_data))
lgbm_test_predictions = np.zeros(len(scaled_test_data))

for fold, (train_idx, val_idx) in enumerate(kf.split(scaled_train_data, y)):
    X_train, X_val = scaled_train_data.iloc[train_idx], scaled_train_data.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    lgbm_model = LGBMRegressor(**lgb_params)

    lgbm_model.fit(X_train, y_train,
                   eval_set=[(X_val, y_val)],
                   eval_metric='rmse',)

    lgbm_fold_preds = lgbm_model.predict(X_val)
    lgbm_fold_test_preds = lgbm_model.predict(scaled_test_data)

    lgbm_predictions[val_idx] = lgbm_fold_preds
    lgbm_true_labels[val_idx] = y_val
    lgbm_test_predictions += lgbm_fold_test_preds / n_splits

overall_metric_lgbm = r2_score(lgbm_true_labels, lgbm_predictions)
print("Overall R^2 (LGBMRegressor):", overall_metric_lgbm)
# Out:
# Overall R^2 (LGBMRegressor): 0.9723686619696512

# %%
lgbm_test_predictions
# Out:
# array([83.42713567, 79.4335091 , 82.17745013, ..., 84.7518744 ,
#        86.20738949, 83.69929013])

# %%
df_sub['y'] = (lgbm_test_predictions *0.7)[:4986] + (catboost_test_predictions*0.0 + xgb_test_predictions*0.3)[:4986]
df_sub.to_csv('Xgboost.csv', index=False)
# Out:
# <>:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# /tmp/ipykernel_2266/2058989123.py:1: SyntaxWarning: 'float' object is not subscriptable; perhaps you missed a comma?
#   df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 df_sub['y'] = lgbm_test_predictions[:,4985] *0.7 + (catboost_test_predictions*0.0[:,4985] + xgb_test_predictions*0.3[:,4985])
#       2 df_sub.to_csv('Xgboost.csv', index=False)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
